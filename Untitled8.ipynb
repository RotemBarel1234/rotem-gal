# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import pandas as pd
import smtplib
import csv
import os
import re
from IPython.display import display
from datetime import datetime,timedelta

# %%
def process_url_request(website_url):
    """
    This function processes the provided URL, gets its data using the requests module,
    and constructs soup data using BeautifulSoup for scraping.
    """
    response = requests.get(website_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    return None

# %%
def convert_to_datetime(date_string):
    date_format = "%d/%m/%Y"
    return datetime.strptime(date_string, date_format)

# %%
def last_day_of_month(year, month):
    if month == 12:  
        next_month = datetime(year + 1, 1, 1)
    else:
        next_month = datetime(year, month + 1, 1)
    return next_month - timedelta(days=1)

# %%
# פונקציה לחישוב הימים שנותרו לחידוש הטסט
def days_until_end_of_month(test_date_str):
    if pd.isna(test_date_str) or not isinstance(test_date_str, str):
        return None
    
    month, year = map(int, test_date_str.split('/'))
    last_day = last_day_of_month(year, month)
    today = datetime.today()
    return (last_day-today).days

# %%
def get_table_data(table):
    data = {}
    for row in table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) == 2:
            key = cols[0].text.strip()
            value = cols[1].text.strip()
            data[key] = value
    return data

# %%
def parse_ad_data(ad):
    title = ad.find('h2', class_='card-title').get_text().split()
    url = f"https://www.ad.co.il{ad.find('a')['href']}"
    ad_soup = process_url_request(url)
    
    if not ad_soup:
        return None
    
    ad_body = ad_soup.find('div', class_="col-xxl-4 col-lg-4 col-md-5")
    price = ad_body.find_all('h2', class_='card-title')[1].text.strip() if len(ad_body.find_all('h2', class_='card-title')) > 1 else 'N/A'
    
    data = {
        'Manufactor': title[0],
        'Model': title[1],
        'Price': price
    }
    
    table = ad_body.find('table', class_='table table-sm mb-4')
    if table:
        data.update(get_table_data(table))
    
    ad_left = ad_soup.find('div', class_="col-xxl-8 col-lg-8 col-md-7")
    if ad_left:
        data['Num_of_pictures'] = len(ad_left.find_all('div', class_="justify-content-center px-1"))
        dates = ad_left.find_all('div', class_='px-3')
        data.update({
            'Create_date': dates[0].text.split()[2] if dates else 'N/A',
            'Last_bump_date': len(dates) > 1 and dates[1].text.split()[3] or 'N/A',
            'Description': ad_left.find('p', class_='text-word-break').text.strip() if ad_left.find('p', class_='text-word-break') else 'N/A'
        })
    
    return data

# %%
base_url = 'https://www.ad.co.il/car?sp261=13899&pageindex='
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

all_ads_data = []
page = 1
while True:
    soup = process_url_request(base_url + str(page))
    if not soup:
        break

    cars = soup.find('div', class_='cards-wrap s m l')
    carAd = cars.find_all('div', class_='card-body p-md-3') if cars else []

    if not carAd:
        break

    for ad in carAd:
        ad_data = parse_ad_data(ad)
        
        if ad_data:
            all_ads_data.append(ad_data)

    page += 1

# יצירת DataFrame 
df = pd.DataFrame(all_ads_data)
column_mapping_english = {
    'שנה': 'Year',
    'יד': 'Hand',
    'ת. הילוכים': 'Gear',
    'נפח': 'Engine_capacity',
    'סוג מנוע': 'Engine_type',
    'בעלות קודמת': 'Prev_ownership',
    'בעלות נוכחית': 'Curr_ownership',
    'אזור': 'Area',
    'עיר': 'City',
    'Price': 'Price',
    'Num_of_pictures': 'Pic_num',
    'Create_date': 'Cre_date',
    'Last_bump_date': 'Repub_date',
    'Description': 'Description',
    'צבע': 'Color',
    'ק"מ': 'Km',
    'טסט עד': 'Test'
}

df.rename(columns=column_mapping_english, inplace=True)
df['Test'] = df['Test'].apply(days_until_end_of_month)

new_order =['Manufactor', 'Year','Model', 'Hand', 'Gear', 'Engine_capacity', 'Engine_type', 'Prev_ownership', 'Curr_ownership', 'Area', 'City', 'Price', 'Pic_num', 'Cre_date', 'Repub_date', 'Description', 'Color', 'Km', 'Test']
df = df[new_order]
# הצגת הנתונים
display(df)
# Out:
#    Manufactor  Year Model Hand      Gear Engine_capacity Engine_type  \
# 0     סיטרואן  2023    C5    1  אוטומטית           1,600       בנזין
# 1     סיטרואן  2019   DS3    1  אוטומטית           1,200      היבריד
# 2     סיטרואן  2022   DS3    1  אוטומטית           1,100       חשמלי
# 3     סיטרואן  2012    C4    3  אוטומטית           1,600       בנזין
# 4     סיטרואן  2017    C4    2  אוטומטית           1,600       בנזין
# ..        ...   ...   ...  ...       ...             ...         ...
# 85    סיטרואן  2019    C4    2  אוטומטית           1,199       בנזין
# 86    סיטרואן  2018    C3    1  אוטומטית           1,200       בנזין
# 87    סיטרואן  2018    C3    1  אוטומטית           1,200       בנזין
# 88    סיטרואן  2018    C1    1   רובוטית             800       בנזין
# 89    סיטרואן  2009    C5    2  אוטומטית           1,900       בנזין
#
#    Prev_ownership Curr_ownership               Area         City      Price  \
# 0           פרטית          פרטית   פתח תקוה והסביבה    פתח תקווה  165,000 ₪
# 1           פרטית          פרטית       מושבים בשרון        שפיים   95,000 ₪
# 2             אחר          פרטית  גדרה יבנה והסביבה         גדרה  139,000 ₪
# 3           פרטית          פרטית   ראש העין והסביבה     ראש העין    3,500 ₪
# 4           פרטית          פרטית    באר שבע והסביבה      באר שבע   45,000 ₪
# ..            ...            ...                ...          ...        ...
# 85            NaN            NaN  נס ציונה - רחובות       רחובות   88,000 ₪
# 86            NaN            NaN     ראשל"צ והסביבה  ראשון לציון   55,900 ₪
# 87            NaN            NaN    חיפה וחוף הכרמל         חיפה   61,000 ₪
# 88          פרטית          פרטית                NaN       דבוריה   41,000 ₪
# 89          פרטית          פרטית     ראשל"צ והסביבה  ראשון לציון   10,000 ₪
#
#     Pic_num    Cre_date  Repub_date  \
# 0         8  19/05/2024  21/05/2024
# 1         4  12/05/2024  12/05/2024
# 2         5  12/05/2024  12/05/2024
# 3         4  09/04/2024  28/04/2024
# 4         4  04/10/2023  25/04/2024
# ..      ...         ...         ...
# 85        0  22/05/2022  22/05/2022
# 86        0  29/04/2022  29/04/2022
# 87        0  28/04/2022  28/04/2022
# 88        0  12/01/2022  12/01/2022
# 89        0  18/10/2021  18/10/2021
#
#                                           Description           Color  \
# 0   סיטרואן סי5 איירקרוס שנת 2023 עם 8600 ק״מ. הדג...  כחול כהה מטאלי
# 1                                       רכב שמור מאוד            סגול
# 2   רכב חשמלי 330 קמ. שמור. שימש כרכב משני. נהיגה ...       לבן מטאלי
# 3   רכב מושלם לחלקים רכב שלם יפה במצב נסיעה בצבע ש...          שמפניה
# 4   סיטרואן C4 פיקאסו 2017\nאוטומט-בנזין-5 דלתות-7...            סגול
# ..                                                ...             ...
# 85  כמו חדש מוחלף בגלל קשיי נגישות לאדם מבוגר\r\nמ...             NaN
# 86  לבוא לקחת. דו צבעי- כסוף עם גג אדום. התחייבות ...             NaN
# 87                                                N/A             NaN
# 88                       תוספות\r\n\t\t\t\tהכל תוספות             לבן
# 89  מוכר את החיה שלי עקב מעבר ללימודים, אוטו מנהלי...            שחור
#
#          Km   Test
# 0     8,600  295.0
# 1    70,000    NaN
# 2    27,400    NaN
# 3   160,000    NaN
# 4   180,000    NaN
# ..      ...    ...
# 85   32,000    NaN
# 86  104,300    NaN
# 87   41,000    NaN
# 88   52,800    NaN
# 89  151,000    NaN
#
# [90 rows x 19 columns]

# %%
print(df.dtypes)
# Out:
# Manufactor          object
# Year                object
# Model               object
# Hand                object
# Gear                object
# Engine_capacity     object
# Engine_type         object
# Prev_ownership      object
# Curr_ownership      object
# Area                object
# City                object
# Price               object
# Pic_num              int64
# Cre_date            object
# Repub_date          object
# Description         object
# Color               object
# Km                  object
# Test               float64
# dtype: object

# %%
df['Manufactor'] = df['Manufactor'].astype(str)
df['Year'] = pd.to_numeric(df['Year'], errors='coerce').astype('Int64')
df['Model'] = df['Model'].astype(str)
df['Hand'] = pd.to_numeric(df['Hand'], errors='coerce').astype('Int64')
df['Gear'] = pd.Categorical(df['Gear'])
df['Engine_capacity'] = pd.to_numeric(df['Engine_capacity'].str.replace(',', ''), errors='coerce').astype('Int64')
df['Engine_type'] = pd.Categorical(df['Engine_type'])
df['Prev_ownership'] = pd.Categorical(df['Prev_ownership'])
df['Curr_ownership'] = pd.Categorical(df['Curr_ownership'])
df['Area'] = df['Area'].astype(str, errors='ignore')
df['City'] = df['City'].astype(str)
df['Price'] = pd.to_numeric(df['Price'].str.replace('[₪,]', '', regex=True), errors='coerce').astype(float)
df['Pic_num'] = df['Pic_num'].astype(int)
df['Cre_date'] = df['Cre_date'].apply(convert_to_datetime)
df['Repub_date'] = df['Repub_date'].apply(convert_to_datetime)
df['Description'] = df['Description'].astype(str)
df['Color'] = df['Color'].astype(str)
df['Km'] = pd.to_numeric(df['Km'].str.replace(',', ''), errors='coerce').astype('Int64')
df['Test'] = pd.to_numeric(df['Test'], errors='coerce').astype('Int64')

print(df.dtypes)
# Out:
# Manufactor                 object
# Year                        Int64
# Model                      object
# Hand                        Int64
# Gear                     category
# Engine_capacity             Int64
# Engine_type              category
# Prev_ownership           category
# Curr_ownership           category
# Area                       object
# City                       object
# Price                     float64
# Pic_num                     int32
# Cre_date           datetime64[ns]
# Repub_date         datetime64[ns]
# Description                object
# Color                      object
# Km                          Int64
# Test                        Int64
# dtype: object

# %%
display(df)
# Out:
#    Manufactor  Year Model  Hand      Gear  Engine_capacity Engine_type  \
# 0     סיטרואן  2023    C5     1  אוטומטית             1600       בנזין
# 1     סיטרואן  2019   DS3     1  אוטומטית             1200      היבריד
# 2     סיטרואן  2022   DS3     1  אוטומטית             1100       חשמלי
# 3     סיטרואן  2012    C4     3  אוטומטית             1600       בנזין
# 4     סיטרואן  2017    C4     2  אוטומטית             1600       בנזין
# ..        ...   ...   ...   ...       ...              ...         ...
# 85    סיטרואן  2019    C4     2  אוטומטית             1199       בנזין
# 86    סיטרואן  2018    C3     1  אוטומטית             1200       בנזין
# 87    סיטרואן  2018    C3     1  אוטומטית             1200       בנזין
# 88    סיטרואן  2018    C1     1   רובוטית              800       בנזין
# 89    סיטרואן  2009    C5     2  אוטומטית             1900       בנזין
#
#    Prev_ownership Curr_ownership               Area         City     Price  \
# 0           פרטית          פרטית   פתח תקוה והסביבה    פתח תקווה  165000.0
# 1           פרטית          פרטית       מושבים בשרון        שפיים   95000.0
# 2             אחר          פרטית  גדרה יבנה והסביבה         גדרה  139000.0
# 3           פרטית          פרטית   ראש העין והסביבה     ראש העין    3500.0
# 4           פרטית          פרטית    באר שבע והסביבה      באר שבע   45000.0
# ..            ...            ...                ...          ...       ...
# 85            NaN            NaN  נס ציונה - רחובות       רחובות   88000.0
# 86            NaN            NaN     ראשל"צ והסביבה  ראשון לציון   55900.0
# 87            NaN            NaN    חיפה וחוף הכרמל         חיפה   61000.0
# 88          פרטית          פרטית                nan       דבוריה   41000.0
# 89          פרטית          פרטית     ראשל"צ והסביבה  ראשון לציון   10000.0
#
#     Pic_num   Cre_date Repub_date  \
# 0         8 2024-05-19 2024-05-21
# 1         4 2024-05-12 2024-05-12
# 2         5 2024-05-12 2024-05-12
# 3         4 2024-04-09 2024-04-28
# 4         4 2023-10-04 2024-04-25
# ..      ...        ...        ...
# 85        0 2022-05-22 2022-05-22
# 86        0 2022-04-29 2022-04-29
# 87        0 2022-04-28 2022-04-28
# 88        0 2022-01-12 2022-01-12
# 89        0 2021-10-18 2021-10-18
#
#                                           Description           Color      Km  \
# 0   סיטרואן סי5 איירקרוס שנת 2023 עם 8600 ק״מ. הדג...  כחול כהה מטאלי    8600
# 1                                       רכב שמור מאוד            סגול   70000
# 2   רכב חשמלי 330 קמ. שמור. שימש כרכב משני. נהיגה ...       לבן מטאלי   27400
# 3   רכב מושלם לחלקים רכב שלם יפה במצב נסיעה בצבע ש...          שמפניה  160000
# 4   סיטרואן C4 פיקאסו 2017\nאוטומט-בנזין-5 דלתות-7...            סגול  180000
# ..                                                ...             ...     ...
# 85  כמו חדש מוחלף בגלל קשיי נגישות לאדם מבוגר\r\nמ...             nan   32000
# 86  לבוא לקחת. דו צבעי- כסוף עם גג אדום. התחייבות ...             nan  104300
# 87                                                N/A             nan   41000
# 88                       תוספות\r\n\t\t\t\tהכל תוספות             לבן   52800
# 89  מוכר את החיה שלי עקב מעבר ללימודים, אוטו מנהלי...            שחור  151000
#
#     Test
# 0    295
# 1   <NA>
# 2   <NA>
# 3   <NA>
# 4   <NA>
# ..   ...
# 85  <NA>
# 86  <NA>
# 87  <NA>
# 88  <NA>
# 89  <NA>
#
# [90 rows x 19 columns]

# %%
folder_path = r"C:\Users\Rotem\Desktop\חומרי לימוד תואר תעשייה וניהול\שנה ג\סמסטר ב\כרייה וניתוח נתונים מתקדם פייתון\project"
csv_path = os.path.join(folder_path, "ad_data.csv")
df.to_csv(csv_path, index=False, encoding='utf-8-sig')

# %%
import urllib.request

url = 'https://data.gov.il/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=5&q=title:jones'
fileobj = urllib.request.urlopen(url)
print(fileobj.read().decode('utf-8'))
# Out:
# {"help": "https://data.gov.il/api/3/action/help_show?name=datastore_search", "success": true, "result": {"include_total": true, "limit": 5, "q": "title:jones", "records_format": "objects", "resource_id": "5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6", "total_estimation_threshold": null, "records": [], "fields": [{"id": "_id", "type": "int"}, {"id": "sug_degem", "type": "text"}, {"id": "tozeret_cd", "type": "numeric"}, {"id": "tozeret_nm", "type": "text"}, {"id": "tozeret_eretz_nm", "type": "text"}, {"id": "tozar", "type": "text"}, {"id": "degem_cd", "type": "numeric"}, {"id": "degem_nm", "type": "text"}, {"id": "shnat_yitzur", "type": "numeric"}, {"id": "mispar_rechavim_pailim", "type": "numeric"}, {"id": "mispar_rechavim_le_pailim", "type": "numeric"}, {"id": "kinuy_mishari", "type": "text"}, {"id": "rank", "type": "float"}], "_links": {"start": "/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=5&q=title%3Ajones", "next": "/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=5&q=title%3Ajones&offset=5"}, "total": 0, "total_was_estimated": false}}

# %%
import urllib.request
import json

url = 'https://data.gov.il/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=10000'
response = urllib.request.urlopen(url)
data = json.loads(response.read())

records = data['result']['records']

# %%
from collections import defaultdict

car_count = defaultdict(int)

for record in records:
    key = (record['tozeret_cd'], record['degem_nm'], record['shnat_yitzur'])
    car_count[key] += 1

# %%
for record in records:
    key = (record['tozeret_cd'], record['degem_nm'], record['shnat_yitzur'])
    record['supply_index'] = car_count[key]

# Print a few examples to see the result
for record in records[:20]:
    print(record)
# Out:
# {'_id': 1, 'sug_degem': 'P', 'tozeret_cd': 798, 'tozeret_nm': 'פיאט פולין', 'tozeret_eretz_nm': 'פולין', 'tozar': 'פיאט', 'degem_cd': 121, 'degem_nm': '169AXBII', 'shnat_yitzur': 2006, 'mispar_rechavim_pailim': 23, 'mispar_rechavim_le_pailim': 152, 'kinuy_mishari': 'PANDA', 'supply_index': 1}
# {'_id': 2, 'sug_degem': 'P', 'tozeret_cd': 778, 'tozeret_nm': 'סיאט ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיאט', 'degem_cd': 26, 'degem_nm': '6J52E4', 'shnat_yitzur': 2012, 'mispar_rechavim_pailim': 2133, 'mispar_rechavim_le_pailim': 713, 'kinuy_mishari': 'IBIZA', 'supply_index': 1}
# {'_id': 3, 'sug_degem': 'P', 'tozeret_cd': 588, 'tozeret_nm': 'מזדה יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'מזדה', 'degem_cd': 621, 'degem_nm': 'BLA2F', 'shnat_yitzur': 2011, 'mispar_rechavim_pailim': 674, 'mispar_rechavim_le_pailim': 163, 'kinuy_mishari': 'MAZDA 3', 'supply_index': 1}
# {'_id': 4, 'sug_degem': 'P', 'tozeret_cd': 798, 'tozeret_nm': 'פיאט פולין', 'tozeret_eretz_nm': 'פולין', 'tozar': 'פיאט', 'degem_cd': 122, 'degem_nm': '169AXBII', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 15, 'mispar_rechavim_le_pailim': 14, 'kinuy_mishari': 'PANDA', 'supply_index': 1}
# {'_id': 5, 'sug_degem': 'P', 'tozeret_cd': 588, 'tozeret_nm': 'מזדה יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'מזדה', 'degem_cd': 51, 'degem_nm': 'GH12F', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 1172, 'mispar_rechavim_le_pailim': 547, 'kinuy_mishari': 'MAZDA 6', 'supply_index': 1}
# {'_id': 6, 'sug_degem': 'P', 'tozeret_cd': 1327, 'tozeret_nm': 'טסלה סין', 'tozeret_eretz_nm': 'סין', 'tozar': 'טסלה', 'degem_cd': 49, 'degem_nm': '3E7F', 'shnat_yitzur': 2021, 'mispar_rechavim_pailim': 426, 'mispar_rechavim_le_pailim': 5, 'kinuy_mishari': 'MODEL 3', 'supply_index': 6}
# {'_id': 7, 'sug_degem': 'P', 'tozeret_cd': 683, 'tozeret_nm': 'סוזוקי-יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'סוזוקי', 'degem_cd': 272, 'degem_nm': 'EZC21S', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 1038, 'mispar_rechavim_le_pailim': 267, 'kinuy_mishari': 'SWIFT', 'supply_index': 1}
# {'_id': 8, 'sug_degem': 'P', 'tozeret_cd': 724, 'tozeret_nm': 'פולקסווגן גרמנ', 'tozeret_eretz_nm': 'גרמניה', 'tozar': 'פולקסווגן', 'degem_cd': 811, 'degem_nm': '1J20D3', 'shnat_yitzur': 2002, 'mispar_rechavim_pailim': 14, 'mispar_rechavim_le_pailim': 384, 'kinuy_mishari': 'BORA', 'supply_index': 1}
# {'_id': 9, 'sug_degem': 'P', 'tozeret_cd': 312, 'tozeret_nm': 'הונדה-יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'הונדה', 'degem_cd': 681, 'degem_nm': 'BE18', 'shnat_yitzur': 2008, 'mispar_rechavim_pailim': 534, 'mispar_rechavim_le_pailim': 116, 'kinuy_mishari': 'FR-V', 'supply_index': 1}
# {'_id': 10, 'sug_degem': 'P', 'tozeret_cd': 156, 'tozeret_nm': 'ביואיק ארהב', 'tozeret_eretz_nm': 'ארה"ב', 'tozar': 'ביואיק', 'degem_cd': 151, 'degem_nm': 'G95GD', 'shnat_yitzur': 2011, 'mispar_rechavim_pailim': 397, 'mispar_rechavim_le_pailim': 109, 'kinuy_mishari': 'LACROSSE', 'supply_index': 1}
# {'_id': 11, 'sug_degem': 'P', 'tozeret_cd': 885, 'tozeret_nm': 'קיה קוריאה', 'tozeret_eretz_nm': 'קוריאה הדרומית', 'tozar': 'קיה', 'degem_cd': 661, 'degem_nm': 'JC5248', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 39, 'mispar_rechavim_le_pailim': 14, 'kinuy_mishari': 'SORENT0', 'supply_index': 1}
# {'_id': 12, 'sug_degem': 'P', 'tozeret_cd': 683, 'tozeret_nm': 'סוזוקי-יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'סוזוקי', 'degem_cd': 101, 'degem_nm': 'FHY51S', 'shnat_yitzur': 2005, 'mispar_rechavim_pailim': 21, 'mispar_rechavim_le_pailim': 18, 'kinuy_mishari': 'IGNIS', 'supply_index': 1}
# {'_id': 13, 'sug_degem': 'P', 'tozeret_cd': 413, 'tozeret_nm': 'טויוטה יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'טויוטה', 'degem_cd': 1001, 'degem_nm': 'ZVW30L-AHXEBW', 'shnat_yitzur': 2010, 'mispar_rechavim_pailim': 1155, 'mispar_rechavim_le_pailim': 190, 'kinuy_mishari': 'PRIUS HYBRID', 'supply_index': 1}
# {'_id': 14, 'sug_degem': 'P', 'tozeret_cd': 961, 'tozeret_nm': 'שברולט ארה"ב', 'tozeret_eretz_nm': 'ארה"ב', 'tozar': 'שברולט', 'degem_cd': 521, 'degem_nm': '1ZH69', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 123, 'mispar_rechavim_le_pailim': 150, 'kinuy_mishari': 'MALIBU', 'supply_index': 2}
# {'_id': 15, 'sug_degem': 'M', 'tozeret_cd': 776, 'tozeret_nm': 'פורד תורכיה', 'tozeret_eretz_nm': 'תורכיה', 'tozar': 'פורד', 'degem_cd': 33, 'degem_nm': 'PT2', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 349, 'mispar_rechavim_le_pailim': 274, 'kinuy_mishari': 'TOURNEO CONNECT', 'supply_index': 1}
# {'_id': 16, 'sug_degem': 'M', 'tozeret_cd': 590, 'tozeret_nm': 'מיצובישי יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'מיצובישי', 'degem_cd': 150, 'degem_nm': 'V78W', 'shnat_yitzur': 2003, 'mispar_rechavim_pailim': 1, 'mispar_rechavim_le_pailim': 4, 'kinuy_mishari': 'PAJERO', 'supply_index': 1}
# {'_id': 17, 'sug_degem': 'P', 'tozeret_cd': 413, 'tozeret_nm': 'טויוטה יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'טויוטה', 'degem_cd': 1181, 'degem_nm': 'NSP120L-CHXGKW', 'shnat_yitzur': 2012, 'mispar_rechavim_pailim': 491, 'mispar_rechavim_le_pailim': 60, 'kinuy_mishari': 'SPACE VERSO', 'supply_index': 1}
# {'_id': 18, 'sug_degem': 'P', 'tozeret_cd': 588, 'tozeret_nm': 'מזדה יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'מזדה', 'degem_cd': 113, 'degem_nm': 'GJ623', 'shnat_yitzur': 2016, 'mispar_rechavim_pailim': 231, 'mispar_rechavim_le_pailim': 57, 'kinuy_mishari': 'MAZDA 6', 'supply_index': 3}
# {'_id': 19, 'sug_degem': 'P', 'tozeret_cd': 588, 'tozeret_nm': 'מזדה יפן', 'tozeret_eretz_nm': 'יפן', 'tozar': 'מזדה', 'degem_cd': 151, 'degem_nm': 'PREMACY_CP19P', 'shnat_yitzur': 2001, 'mispar_rechavim_pailim': 51, 'mispar_rechavim_le_pailim': 334, 'kinuy_mishari': 'PREMACY', 'supply_index': 1}
# {'_id': 20, 'sug_degem': 'P', 'tozeret_cd': 961, 'tozeret_nm': 'שברולט ארה"ב', 'tozeret_eretz_nm': 'ארה"ב', 'tozar': 'שברולט', 'degem_cd': 61, 'degem_nm': '1ZH69', 'shnat_yitzur': 2009, 'mispar_rechavim_pailim': 105, 'mispar_rechavim_le_pailim': 187, 'kinuy_mishari': 'MALIBU LT', 'supply_index': 2}

# %%
import urllib.request
import json
from collections import defaultdict

# שלב 1: משיכת הנתונים מה-API
url = 'https://data.gov.il/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6 '
response = urllib.request.urlopen(url)
data = json.loads(response.read())

records = data['result']['records']

# שלב 2: קיבוץ הנתונים לפי תוצר, דגם ושנתון
car_count = defaultdict(int)
for record in records:
    key = (record.get('tozar'), record.get('degem_nm'), record.get('shnat_yitzur'))
    car_count[key] += 1

# בדיקה ראשונית של הקיבוץ
print("Sample of grouped data:")
sample_keys = list(car_count.keys())[:-1]
for key in sample_keys:
    print(f"{key}: {car_count[key]}")

# שלב 3: חיפוש כל הרכבים של סיטרואן
citroen_records = [record for record in records if record.get('tozar') == 'סיטרואן']

# בדיקה ראשונית של הסינון
print(f"Number of Citroen records: {len(citroen_records)}")
print("First 5 Citroen records:")
for record in citroen_records[:-1]:
    print(record)

# שלב 4: הוספת מדד ההיצע לרכבים של סיטרואן
for record in citroen_records:
    key = (record.get('tozar'), record.get('degem_nm'), record.get('shnat_yitzur'))
    record['supply_index'] = car_count[key]

# שלב 5: הצגת התוצאות
print("First 20 Citroen records with supply index:")
for record in citroen_records[:-1]:  # הדפסת 20 רשומות ראשונות לדוגמה
    print(record)
# Out:
# Sample of grouped data:
# (798, '169AXBII', 2006): 1
# (778, '6J52E4', 2012): 2
# (588, 'BLA2F', 2011): 1
# (798, '169AXBII', 2009): 1
# (588, 'GH12F', 2009): 2
# (1327, '3E7F', 2021): 18
# (683, 'EZC21S', 2009): 1
# (724, '1J20D3', 2002): 3
# (312, 'BE18', 2008): 3
# (156, 'G95GD', 2011): 1
# (885, 'JC5248', 2009): 1
# (683, 'FHY51S', 2005): 1
# (413, 'ZVW30L-AHXEBW', 2010): 1
# (961, '1ZH69', 2009): 7
# (776, 'PT2', 2009): 1
# (590, 'V78W', 2003): 6
# (413, 'NSP120L-CHXGKW', 2012): 3
# (588, 'GJ623', 2016): 3
# (588, 'PREMACY_CP19P', 2001): 1
# (885, 'TB2812', 2000): 1
# (885, 'DN412B', 2014): 5
# (839, 'ZZE121L-DEPDKW', 2007): 2
# (194, '639.815', 2006): 3
# (771, 'LZLF06', 2015): 4
# (624, 'PATROL SE A TEST61', 2002): 1
# (751, 'VM58L', 2008): 4
# (588, 'BK12Z', 2007): 4
# (961, 'P85SC', 2012): 3
# (388, 'RS65', 2010): 1
# (830, 'ML320', 1998): 1
# (731, 'KOMBI TRANSIT 300S', 2002): 1
# (751, 'JM6EE', 2014): 2
# (481, 'H-1 WWH7H', 2001): 5
# (940, 'B57BB5 CLIO RT3', 1997): 1
# (675, 'RZG00', 2020): 2
# (588, 'BLB2F', 2013): 1
# (676, 'NH33MD', 2017): 2
# (361, '964-95', 1997): 2
# (481, 'AG51G', 2002): 2
# (771, 'BZA10A', 2011): 1
# (351, 'HSDCW6', 2016): 6
# (1321, 'LP5SEF', 2023): 3
# (676, '1Z338C', 2008): 5
# (676, '5E53FD', 2016): 7
# (281, 'J102LG-JPXFW', 2001): 1
# (19, 'GABCZG', 2019): 2
# (731, 'WA6-M', 2015): 2
# (114, '211.006', 2006): 2
# (737, '182BB1AA', 2001): 1
# (413, 'KDJ150L-GKAEYW', 2013): 3
# (739, 'CC5FS9', 2014): 4
# (351, 'HJD20', 2021): 8
# (676, '5L7CFD', 2016): 1
# (650, 'GC3EL3R', 1997): 3
# (637, 'FFAJ11', 2019): 6
# (712, 'NOB1F', 2010): 1
# (637, 'FFAJ11', 2021): 8
# (869, 'JDAB', 2012): 1
# (737, '176AQ55F', 1998): 2
# (288, 'אספרו- JA19W', 1997): 1
# (885, 'CD81DG', 2019): 1
# (143, 'AT51', 2002): 2
# (588, 'BN647', 2017): 3
# (416, 'PC811D', 2013): 1
# (672, 'MXPA11L-BHXNBW', 2021): 6
# (962, '1WH19', 2000): 2
# (676, 'NU73BD', 2018): 2
# (139, 'UN8F97', 2008): 1
# (624, 'BCAN15', 1996): 3
# (281, 'שרייד_G200LS-GPDE', 1996): 1
# (341, 'EX 2.2 אקורד', 1997): 1
# (312, 'GD18', 2008): 3
# (443, 'Z14U', 2017): 2
# (19, '4D2GHK', 2000): 1
# (961, '1JC69', 1997): 2
# (386, 'S40 SE VS16', 1999): 1
# (724, '2DE1B2', 2001): 1
# (885, 'DC2233', 2002): 2
# (312, 'SHUTTLE-2.3ILS', 1998): 1
# (114, '211.061', 2002): 2
# (481, 'SH81W', 2007): 5
# (676, 'GLXI 654', 1996): 1
# (676, 'NH34MD', 2018): 1
# (712, 'SOK', 2008): 2
# (869, 'UB8K', 2008): 3
# (676, '3T53JC', 2013): 1
# (650, 'SJ5EL2C', 2018): 2
# (722, 'TA61', 2022): 1
# (603, 'K74T', 2003): 6
# (143, 'NE31', 2007): 3
# (590, 'V46W', 1999): 5
# (644, '900S', 1997): 2
# (798, '312AXA11', 2010): 2
# (19, '4F20NL', 2009): 1
# (899, 'GP44R', 2008): 1
# (683, 'ERC31S', 2007): 6
# (624, 'JGAT32', 2021): 8
# (388, 'LW61', 2000): 2
# (19, '8RB0MY', 2015): 2
# (724, '7J0-7EA112', 2013): 2
# (676, '3V34PD', 2018): 7
# (593, '246.201', 2013): 1
# (187, 'GUN126L-DTTSXW', 2021): 2
# (885, 'PH813D', 2015): 1
# (624, 'BCAV37', 2015): 4
# (143, '4H31', 2019): 2
# (465, 'A51L', 2004): 1
# (174, 'S3CAA', 2021): 1
# (388, 'V70 GLT LW55', 1998): 1
# (388, '855GLE  2500', 1996): 1
# (672, 'NHP130L-CHXNBW', 2019): 8
# (869, 'JFLG', 2019): 1
# (624, 'BCAV36', 2010): 4
# (899, 'TOWN COUNTRY GP44R', 2002): 2
# (19, '8L1A48', 2000): 2
# (712, 'C02', 2009): 1
# (676, '1Z32LD', 2011): 2
# (593, '212.054', 2011): 3
# (496, 'GJRHYK', 2003): 3
# (104, 'AHL48', 2008): 2
# (590, 'CS3ASRJEL6', 2008): 4
# (830, '167.117', 2022): 1
# (806, 'VITO_112CDI', 2001): 4
# (778, '1P1691', 2011): 1
# (644, 'EB4', 2002): 3
# (727, 'C113FZ', 2022): 2
# (739, 'WA5FXC', 2008): 1
# (263, 'K3R', 2021): 2
# (590, 'CW4WXTHHL6', 2012): 4
# (730, 'בלגיה/120טרנזיט', 1998): 8
# (593, 'C 240', 2001): 1
# (940, 'FLBHA6', 2007): 1
# (727, '6R19V7', 2013): 4
# (496, '7NBHW6/3', 2017): 2
# (739, '7EDJYT', 1999): 1
# (727, '9N11G4', 2002): 1
# (312, 'RD18', 1998): 3
# (481, 'C851C', 2022): 1
# (481, 'CT41B', 2015): 2
# (724, '7EA112', 2012): 2
# (729, 'FAA6', 2008): 1
# (421, 'ZT81B', 2010): 1
# (928, 'KW25B5', 2012): 2
# (840, 'A85SX', 2015): 3
# (672, 'NSP131L-CHXNBW', 2018): 8
# (940, '2R5A1H', 2014): 2
# (361, 'TS79', 2004): 2
# (239, 'JXAN', 2022): 5
# (346, 'FK27', 2008): 1
# (590, 'ראנר N21WSNUEL6', 1998): 1
# (739, '8D5GZT/S', 2017): 2
# (727, '6R-6C12EZ', 2015): 2
# (143, 'EA11', 2010): 1
# (301, '2K-SABT22', 2017): 1
# (465, 'SOVEREIGN', 1996): 1
# (516, 'SXHNPN/ABS', 2018): 1
# (737, '199BXW1A', 2011): 1
# (152, '118.386', 2022): 4
# (413, 'ZSA44L-ANXMPW', 2016): 3
# (771, '5RB20A', 2015): 4
# (593, '204.031', 2012): 2
# (869, 'JWDG', 2018): 3
# (143, 'VP3+', 2012): 1
# (19, '8RB0AA', 2014): 6
# (74, '939AXB1B', 2010): 1
# (593, '295.121', 2023): 1
# (19, '4F201L', 2011): 1
# (724, '3B6134', 2004): 1
# (722, '11DT', 2022): 1
# (739, 'F35GFR', 2019): 1
# (802, 'LMF-D3', 2000): 1
# (728, 'P8T', 2020): 3
# (19, '8PAB2X', 2007): 3
# (590, 'GF7WXTXXZL6', 2014): 6
# (869, 'N5GK', 2011): 1
# (712, 'GOF', 2006): 2
# (637, 'FBAF15', 2019): 6
# (869, 'JFAG', 2014): 3
# (672, 'NHP130L-CHXNBW', 2020): 6
# (885, 'BX312B', 2016): 5
# (103, 'F7BDD', 2005): 3
# (32, 'XS11', 2015): 1
# (593, '293.890', 2021): 2
# (739, 'CC5FS9', 2012): 1
# (839, 'ZYX11L-AHXNBW', 2020): 6
# (413, 'LN165L - TRMDXW', 1998): 2
# (806, '639.815', 2010): 3
# (33, 'XEP08', 2017): 2
# (443, 'A16E', 2011): 1
# (830, '167.119', 2021): 1
# (603, 'NKA4', 2009): 1
# (143, '318IS-2A_BE 81', 1999): 1
# (787, 'CA1FUR', 2021): 3
# (551, '8X1ADG', 2015): 2
# (624, 'JGAT32', 2020): 5
# (739, 'MCBHZW/S2F000', 2018): 2
# (312, 'GK38', 2018): 7
# (724, '5G12DZ', 2014): 1
# (593, '213.004', 2019): 10
# (885, 'B351AJ', 2021): 4
# (730, 'JHH', 2018): 1
# (941, 'LDHA', 1997): 1
# (778, 'KJ15KZ', 2018): 9
# (404, 'AAZH26L-AWXLBW', 2022): 2
# (817, 'XTRHHA', 2015): 3
# (940, 'LAGUNA 2.0 B56LOF', 1999): 1
# (253, 'J3813', 2021): 2
# (404, 'AGZ10L-AWTLTW', 2015): 1
# (676, '5E53MD', 2015): 2
# (624, 'TBNJ50', 2015): 1
# (739, '406 STDT 8BP8CE', 1997): 1
# (650, 'ZC6DLE8', 2016): 1
# (676, '5E33ND', 2019): 9
# (715, '162221', 2015): 1
# (672, 'SCP90L-CHGGKW', 2009): 2
# (143, '520 IA DD21', 1997): 1
# (177, '263WXL11', 2015): 4
# (941, 'ZA2BX', 2021): 3
# (590, 'N84WLRUCL6', 2002): 3
# (114, 'S 320', 2003): 1
# (114, '209.365', 2002): 2
# (593, '207.347', 2010): 1
# (143, '318IS A BE61', 1996): 1
# (19, '8K20QC', 2008): 1
# (443, 'A240', 2018): 1
# (388, 'SW65', 2005): 1
# (312, 'RW28', 2021): 4
# (143, 'VG51', 2009): 1
# (869, 'BG8B', 2007): 7
# (74, '955AXR11', 2011): 6
# (798, '312AXA11', 2020): 5
# (593, '204.981', 2011): 2
# (194, '639.603', 2006): 7
# (650, 'GP7BLRC', 2013): 2
# (416, 'HN516G', 2018): 2
# (351, 'HJD20', 2022): 12
# (188, 'BD6EC', 2018): 2
# (143, '4V31', 2019): 1
# (885, 'JE5538', 2008): 2
# (312, 'ES95', 2004): 1
# (143, '328I 4 AM51', 1998): 1
# (770, 'F142 BBE', 2017): 1
# (413, 'AXAL52L-ANXMBW', 2023): 3
# (778, 'KM76EZ', 2021): 3
# (920, '453.342', 2016): 3
# (351, 'HJD40', 2022): 2
# (259, 'DJCT', 2021): 1
# (152, '118.384', 2020): 6
# (351, '5SDL1A', 2018): 2
# (403, 'PSCFBB/W1C000', 2014): 1
# (588, 'BL12Z', 2009): 2
# (724, '5212G5', 2010): 1
# (416, 'HN816G', 2016): 6
# (751, 'CM6E7', 2017): 2
# (143, 'GL61', 2002): 1
# (724, '1600 CL גולף', 1997): 1
# (288, 'TA48Y', 2000): 2
# (155, 'ES76', 2006): 7
# (676, '5E33FD', 2017): 1
# (413, 'ZSA44L-ANXXPW', 2015): 3
# (683, 'RZC83S', 2019): 3
# (481, 'BT51D', 2009): 5
# (739, '2AKFWF', 2001): 5
# (588, 'DEA45', 2013): 2
# (496, '3A5GZT/2SM', 2017): 1
# (650, 'GT3BLGC', 2018): 1
# (19, '8D20C4', 2000): 1
# (676, '3T43LD', 2010): 2
# (650, 'GC3HL3R', 2001): 3
# (715, '1624Q5', 2012): 1
# (299, 'LYE21S', 2016): 4
# (817, 'MFWJYB', 2002): 9
# (603, 'K74T', 2001): 5
# (962, 'LUMINA-S_1WL69', 1999): 1
# (751, 'JJ7E5', 2014): 3
# (481, 'JN81D', 2009): 2
# (739, '8B6FZR', 2003): 2
# (388, 'RS65', 2008): 2
# (312, 'CL76', 2007): 5
# (845, 'B351C', 2015): 3
# (962, '1WF19', 2002): 1
# (676, '5423KC', 2010): 2
# (650, 'BM5BL1C', 2011): 3
# (103, 'SDL68', 2012): 3
# (739, '2AKFWR', 2003): 4
# (413, 'ACV30L-AEPNKW', 2003): 2
# (739, '7AKDX2', 1997): 2
# (676, '1Z338C', 2006): 2
# (177, '263WXC1A', 2012): 2
# (603, 'KB4TNJRUZL6', 2014): 2
# (676, '5452JD', 2011): 3
# (590, 'ואגון N43WLRUEL6', 1998): 1
# (885, 'DN412B', 2016): 3
# (341, 'CG42', 2001): 2
# (590, 'V88WMYHJL6', 2015): 2
# (593, 'גג+_E250D מרצדס', 1996): 1
# (103, 'CORSA-B SBF 68', 1998): 2
# (588, 'DE145', 2009): 2
# (778, '6K52K6', 2001): 1
# (413, 'GRJ125L-GJPEKW', 2005): 1
# (778, '6J52G7', 2009): 2
# (127, 'UBS73', 2004): 7
# (588, 'HATCHBAI626-GF 14S', 1999): 1
# (676, '3T43JC', 2012): 2
# (139, 'DEA25', 2011): 2
# (739, '0E5FVA/1', 2011): 2
# (288, 'רייסר סןפר-TA19Y', 1996): 1
# (941, 'LNAB', 2000): 5
# (739, '2HNFUF', 2003): 2
# (185, 'AB7A', 2017): 2
# (778, '6L15C4', 2008): 2
# (730, 'DYB', 2014): 19
# (778, '1P12H1', 2012): 2
# (413, 'AEPDKW-AE111L', 1998): 2
# (731, 'BA7', 2012): 5
# (588, 'GH12F', 2010): 4
# (590, 'V46W', 2000): 7
# (683, 'JTDA4V', 2010): 3
# (268, '8UB08Y', 2013): 2
# (928, 'JAACOE', 2002): 1
# (751, 'CM6E7', 2016): 3
# (739, '3HRFNF', 2005): 1
# (724, '3B23E8', 2000): 1
# (961, 'CR14526', 2016): 5
# (798, '169AXB11', 2010): 1
# (778, '6J52E4', 2014): 4
# (481, 'JF31M', 1997): 1
# (731, 'WA6-M', 2012): 1
# (798, '312AXA11', 2017): 5
# (885, 'JC5218', 2005): 1
# (416, 'FF2423', 2010): 4
# (361, '940 GL', 1998): 4
# (416, 'FF2423', 2009): 2
# (481, 'DC51D', 2008): 2
# (588, 'KEC97', 2013): 4
# (551, '8XFASG', 2017): 3
# (413, 'NHW20L-AHEEBW', 2008): 4
# (1020, 'JDCH', 2019): 4
# (312, 'FD16', 2007): 3
# (312, 'GP18', 2014): 2
# (416, 'HN813G', 2015): 4
# (672, 'NHP130L-CHXNBW', 2015): 2
# (683, 'RZCA3S', 2023): 1
# (817, 'S1KFXD', 1999): 1
# (143, '8E11', 2017): 2
# (388, 'SW53', 2001): 2
# (928, 'JM0U0A', 2005): 2
# (143, 'NA51', 2005): 1
# (103, 'XCF68', 2006): 1
# (739, '0E5FVA/1', 2015): 3
# (885, 'GN414B', 2014): 4
# (676, '1U2154', 2009): 3
# (973, 'TFS86', 2016): 9
# (634, 'TWUR20', 2003): 4
# (481, 'KM81C', 2022): 1
# (386, 'VS70', 2003): 1
# (683, 'GJB74V', 2022): 5
# (941, 'LTGM', 2003): 6
# (672, 'NSP90L-CHFRKW', 2010): 2
# (114, '203.008', 2005): 2
# (413, 'AE101L AEPDKW', 1997): 1
# (940, 'BBOFCF', 2003): 1
# (143, 'DM41', 1999): 1
# (676, '5E538C', 2017): 1
# (19, '8PAA7U', 2005): 2
# (551, '8XKAJG', 2016): 2
# (676, 'NH33PD', 2016): 1
# (928, 'JZ09B3', 2013): 3
# (676, '5E34MD', 2016): 4
# (650, 'BM9AL49', 2010): 1
# (724, '5N-AD12PY', 2018): 2
# (771, '7RBJ0D', 2019): 1
# (727, 'C113FZ', 2021): 3
# (817, 'DCRFNE', 2002): 4
# (885, 'JT813B', 2013): 2
# (817, 'XS9HUC', 2008): 2
# (973, 'TFS77', 2006): 8
# (593, '212.047', 2011): 1
# (683, 'FTA03V', 2003): 2
# (817, 'XCRHKH', 2008): 3
# (775, 'K48', 2008): 1
# (928, 'KAN-RL FCOEDF', 2000): 1
# (885, 'CS81FG', 2023): 1
# (32, 'SR31', 2013): 5
# (724, '1J21C4', 2001): 1
# (187, 'GUN125L-DTTMHW', 2016): 3
# (194, '639.605', 2005): 3
# (33, 'MAP08', 2015): 5
# (676, '5E33FD', 2016): 5
# (481, 'DN51B', 2006): 1
# (672, 'NSP130L-CHXNKW', 2015): 6
# (650, 'SK9DY5L', 2022): 1
# (676, '1Z32MD', 2011): 2
# (724, '7EA112', 2010): 2
# (103, 'XCF68', 2002): 8
# (590, 'V68W', 2001): 4
# (603, 'K64T', 2005): 2
# (928, 'KC0SAA', 2007): 2
# (650, 'GP7ELUC', 2017): 2
# (676, 'קומבי GLX -654', 1997): 1
# (481, 'JF21R', 2000): 6
# (712, 'CA1ET', 2014): 1
# (928, 'CB1NOF', 2002): 1
# (676, '5E348C', 2017): 3
# (727, '6N20Q4', 2002): 1
# (778, '6K13F1', 2001): 2
# (885, 'FA2223', 1998): 1
# (727, '9N31M4', 2008): 2
# (724, 'AU-5G12HZ', 2016): 3
# (778, '1M13H3', 2002): 2
# (731, 'WA6S', 2011): 1
# (727, '9KVF1Y', 2000): 1
# (603, 'NKB4', 2008): 1
# (1294, 'J4B19', 2022): 2
# (413, 'LXH12L - SBSRXW', 1999): 1
# (737, '188BXB11', 2004): 2
# (301, '2CBS85', 2011): 7
# (588, 'BM52A', 2014): 4
# (724, '3C2346', 2008): 1
# (590, 'V78W', 2006): 4
# (156, '4HR69', 2001): 1
# (288, 'נקסיה  TA08V', 1996): 1
# (722, 'KT01', 2019): 3
# (724, '7DK2Y2', 2003): 1
# (650, 'WXEBL6U', 2007): 2
# (253, 'J3811', 2017): 1
# (885, 'PH813B', 2016): 8
# (941, 'XWMB', 1997): 2
# (253, 'J3813', 2016): 8
# (114, '906.633', 2008): 6
# (778, '6L1536', 2004): 2
# (187, 'GUN125L-DTTSXW', 2022): 2
# (869, 'GP45R', 2005): 1
# (676, '1Z52GC', 2009): 2
# (910, 'JB31', 2018): 1
# (588, 'BM52A', 2016): 1
# (676, '3U423B', 2006): 2
# (19, '8L1BI8', 2000): 2
# (188, 'PD5EC', 2015): 7
# (981, 'AX9EV', 2019): 4
# (869, '6B8K', 2007): 3
# (817, 'DC6FZE', 2005): 2
# (885, 'PH81BD', 2020): 2
# (727, '6V50T6', 2001): 1
# (724, '7DA1K2', 1999): 1
# (143, '3A11', 2015): 5
# (413, 'LN145L - TRMDSW', 2000): 1
# (650, 'GDCGL1B', 2008): 2
# (727, '6N10F3', 1999): 1
# (637, 'JBNJ10', 2014): 2
# (727, '9N31M7', 2008): 4
# (143, 'GL41', 2002): 1
# (593, '110D', 1998): 7
# (19, '8PAS4L', 2012): 1
# (593, '176.042', 2013): 5
# (593, '906.633', 2013): 2
# (593, '253.346', 2017): 2
# (624, 'JFNT32', 2017): 2
# (928, 'FDCMD5', 2003): 1
# (459, '7L6053', 2009): 1
# (481, 'JT81V', 2015): 1
# (19, '4F201L', 2007): 2
# (143, '1R51', 2018): 6
# (676, '6Y22J4', 2007): 4
# (19, '8K20FL', 2010): 1
# (351, 'HJD40', 2021): 4
# (724, '1J20D3', 2003): 3
# (941, 'LAAA', 2008): 4
# (103, 'SD9EM', 2016): 3
# (143, 'UF51', 2007): 4
# (676, '5E34MD', 2017): 4
# (388, 'FS47', 2011): 1
# (19, '4H20VA', 2012): 1
# (885, 'DN512B', 2015): 6
# (683, 'פתוח סמוראי SJ800', 1996): 1
# (722, 'VJ91', 2019): 1
# (544, 'JSDAC7', 2015): 2
# (413, 'GDJ150L-GKTEYW', 2016): 6
# (114, '211.007', 2007): 4
# (941, 'RFMW', 2000): 1
# (885, 'BX511B', 2017): 2
# (644, '900S', 1998): 1
# (724, "'דלת3_1J12J4", 1999): 1
# (734, 'DB3', 2011): 2
# (1327, '3E7E', 2022): 11
# (676, '6Y5214', 2007): 5
# (676, 'NH33PD', 2014): 3
# (490, 'KGB10L-AHMGKW', 2013): 1
# (943, 'DA0F0D RMG RN 1.6', 1997): 1
# (253, 'JB81B', 2022): 4
# (593, '212.061', 2016): 1
# (672, 'MDZ542L-LBTDGW', 2021): 1
# (676, '3V33ND', 2022): 3
# (404, 'AXZH10L-AEXGBW', 2019): 2
# (722, 'FG81', 2009): 1
# (416, 'PG81AB', 2021): 3
# (404, 'AGZ10L-AWTLTW', 2020): 2
# (143, '1A31', 2012): 2
# (590, 'NA4W', 2006): 5
# (683, 'GJB74V', 2021): 8
# (676, '5L7BFD', 2015): 1
# (739, 'MCYHZR/C2B000', 2019): 2
# (990, 'FVP0DG', 2020): 1
# (817, 'N2E300', 1996): 2
# (683, 'FTL52V', 2002): 2
# (32, 'XS51', 2016): 2
# (778, '6J57J7', 2014): 2
# (817, 'N2E400', 1996): 6
# (593, '206.046', 2023): 1
# (590, 'L-400  PA3W', 1998): 1
# (156, '4HP69', 2001): 2
# (19, '8PAB29', 2006): 2
# (361, 'FW44', 2011): 1
# (185, 'AB7A', 2021): 1
# (724, '2DD132', 2001): 1
# (724, '5M102A', 2008): 1
# (683, 'FJB43V', 2003): 2
# (817, 'NC9HR8/1', 2011): 2
# (839, 'ZYX10L-AHXEBW', 2019): 4
# (771, 'RFB00', 2023): 5
# (739, '4ELFZ4', 1996): 1
# (695, '31AA', 2020): 1
# (143, '316 I-4 A CA81', 1996): 1
# (739, '6DRFJF', 2007): 6
# (751, 'CJ6E7', 2017): 1
# (430, 'ZWE186L-DWXNBW', 2017): 5
# (74, '932A2000', 2000): 1
# (588, 'DK6W7', 2017): 5
# (778, '6J13E4', 2015): 1
# (481, 'NM81X', 2006): 3
# (496, '7N9HP0', 2015): 2
# (413, 'GDJ150L-GKTEYW', 2019): 7
# (74, '955AXY1B', 2014): 2
# (19, '8P1A5X', 2008): 2
# (899, 'S5D1', 2010): 4
# (185, 'FCAC11', 2008): 2
# (388, 'LS51', 1997): 1
# (19, 'GY-8YAS3Y', 2021): 1
# (778, '6J-6P55KZ', 2017): 1
# (1327, '3E7E', 2021): 18
# (361, 'AS44', 2011): 3
# (817, 'DCRHZE', 2003): 3
# (593, '204.349', 2012): 1
# (676, '5E54LD', 2014): 1
# (76, 'PD8EC', 2015): 7
# (481, 'K3815', 2019): 7
# (281, 'A101LS-GPDE', 1998): 1
# (19, '4G201Y', 2014): 2
# (778, 'KM7BEZ', 2021): 2
# (817, 'LARFKC', 2006): 1
# (743, 'USHNSS', 2021): 10
# (724, '7HC-7EB137', 2014): 3
# (798, '169AXB11', 2005): 1
# (21, '4LB0PL', 2009): 6
# (990, '8VSA6G', 2014): 7
# (590, 'CS3ASRJEL6', 2007): 6
# (603, 'K74TL', 2004): 1
# (928, 'JM1R0A', 2006): 2
# (778, '6L12G3', 2004): 4
# (351, 'HSDCUN', 2017): 3
# (863, 'KUN15L-PRMDYW', 2006): 1
# (676, '1Z326C', 2007): 7
# (940, '2R401E', 2013): 4
# (19, '8VAA6G', 2013): 2
# (413, 'KDJ150L-GKAEYW', 2012): 4
# (593, '176.052', 2014): 1
# (616, '164.122', 2006): 1
# (776, 'FCC', 2017): 2
# (143, 'DM61', 1999): 2
# (941, 'EA7BN', 2020): 1
# (588, 'DK6W7', 2018): 4
# (413, 'GRJ120L-GKAEKW', 2007): 6
# (735, 'CAYENNE 9PA', 2005): 1
# (234, 'סגור CYJ-L', 2001): 2
# (990, 'FV906G', 2018): 1
# (734, 'DAW', 2005): 4
# (121, '312YXG1A', 2014): 2
# (19, '4GA01Y', 2014): 3
# (653, 'FBUK13', 2013): 3
# (839, 'ZYX11L-AHXKBW', 2021): 5
# (650, 'GE7BLAS', 2010): 2
# (737, '176AC55A', 1997): 4
# (152, '117.352', 2016): 2
# (798, '312AXD1A', 2015): 3
# (735, '971', 2019): 3
# (712, 'CA1ET', 2013): 1
# (806, '447.815', 2020): 2
# (928, 'KW0BB5', 2011): 1
# (724, '1T32B4', 2013): 1
# (899, 'C1BG', 2013): 8
# (361, 'UZ25', 2019): 2
# (590, 'PA5W', 1999): 1
# (845, 'B351C', 2017): 5
# (710, '900SE', 1996): 1
# (637, 'JBNJ10', 2010): 8
# (737, '199BXB1A', 2007): 2
# (593, '205.342', 2017): 1
# (724, '5N-AD13QT', 2018): 4
# (288, 'NUBIRA A16DMS', 1997): 1
# (301, '7HJS03', 2005): 1
# (413, 'KDJ120L-GKAEYW', 2007): 10
# (734, 'DFW', 2003): 4
# (19, '8VFCGG', 2017): 2
# (588, 'DM6W7', 2022): 8
# (361, 'CM85', 2006): 1
# (817, 'VEAHHW-P2B00K', 2018): 1
# (722, 'FB71', 2004): 2
# (281, 'J21OLG-GQXFW', 2011): 2
# (739, '7ARFX2', 1997): 1
# (806, '447.705', 2022): 1
# (650, 'BR9BLK9', 2011): 3
# (465, 'A02M', 2007): 3
# (496, '3DAHXT/1S', 2015): 1
# (941, 'WA2K', 2015): 2
# (361, 'AS48', 2012): 2
# (481, 'S381D', 2021): 1
# (19, '8V1S4L', 2013): 1
# (830, '164.186', 2010): 2
# (885, 'KU814D', 2013): 4
# (361, 'CM98', 2007): 1
# (114, '219.372', 2008): 1
# (593, '245.233', 2009): 2
# (806, '447.815', 2022): 1
# (676, '1Z32DD', 2013): 2
# (624, 'GCAV36', 2012): 1
# (19, '8E50BH', 2002): 2
# (724, '7HJ172', 2007): 2
# (634, 'JVWR51', 2010): 2
# (281, 'G303LG-GMNEW', 1997): 1
# (361, 'MC67', 2011): 1
# (724, '7EJ137', 2016): 1
# (739, '2E8HXF', 2004): 1
# (593, '213.004', 2022): 7
# (650, 'GE2BL3S', 2008): 4
# (465, 'BB4BX', 2018): 1
# (416, 'FF5242', 2011): 2
# (451, 'JC7E8', 2015): 8
# (1213, 'EEKRP', 2022): 1
# (19, '8T3SBL', 2011): 1
# (634, 'CTND23', 2021): 1
# (19, '8B-F53CAY', 2018): 1
# (74, '952AXA2', 2022): 1
# (513, '844AXH12', 2010): 3
# (885, 'MC5C1', 2018): 7
# (869, 'JXDN', 2020): 4
# (351, 'HSDJ9G', 2016): 4
# (885, 'BX312B', 2014): 3
# (445, 'RU18', 2016): 2
# (312, 'GK38', 2017): 3
# (197, '463.349', 2022): 1
# (481, 'J1442F65', 2021): 1
# (481, 'TC61E', 2012): 1
# (676, 'NY-5AZJJ2', 2023): 4
# (177, '263WXD1B', 2015): 7
# (312, 'GD17', 2004): 1
# (724, '1T2CB3', 2010): 1
# (724, '5N22CY', 2015): 1
# (488, 'GSL30L-PRTQKA', 2014): 1
# (590, 'V75W', 2006): 1
# (593, '205.004', 2018): 3
# (817, 'VFAHHW-B2B01B', 2019): 1
# (590, 'GF7WXTXXL6', 2017): 7
# (650, 'GJ2EL1C', 2016): 5
# (1229, '3E7E', 2021): 14
# (676, 'NW-NW14JD', 2023): 1
# (644, 'EF4', 2002): 3
# (869, 'JFCG', 2012): 1
# (724, '7EJ137', 2010): 3
# (817, 'N2NFZF', 1999): 1
# (127, 'UBS73', 2002): 7
# (697, 'AA-KF13D1', 2015): 3
# (301, '2K-SAJT26', 2020): 3
# (817, 'A45GFR/C1F000', 2019): 1
# (863, 'KUN15L-TRMDYW', 2006): 1
# (1426, 'EEUA5', 2024): 2
# (299, 'EXB32', 2012): 4
# (481, 'SU81B', 2016): 2
# (593, '246.242', 2013): 2
# (817, 'ACYHZR', 2020): 4
# (735, '92A', 2012): 3
# (885, 'MC5C1', 2017): 3
# (724, '7HH103', 2007): 1
# (590, 'GF6WXLXFZL6', 2016): 2
# (32, 'SU91', 2013): 1
# (869, 'JFCG', 2015): 1
# (413, 'GDJ150L-GKTEYW', 2021): 12
# (76, 'BD8EC', 2017): 2
# (724, '7HH103', 2005): 5
# (676, 'NS749Z', 2020): 1
# (676, '1Z53DD', 2010): 1
# (283, 'FYBCAY', 2017): 5
# (32, 'ML31', 2009): 1
# (361, 'FW47', 2011): 2
# (301, '2K-SABT26', 2016): 1
# (194, '639.603', 2005): 4
# (734, 'DA3', 2010): 5
# (869, 'JXAN', 2020): 3
# (416, 'PC81BD', 2015): 3
# (724, '1J23Q4', 2001): 1
# (33, 'GM8EE', 2012): 2
# (817, 'VEEHS7', 2022): 2
# (771, 'BZAR0A', 2011): 2
# (973, 'TFS85', 2008): 4
# (650, 'GG9GL6W', 2007): 2
# (603, 'XTA03', 2021): 5
# (941, 'RTZL', 1997): 2
# (676, 'NX33JD', 2021): 4
# (650, 'BM5AL1C', 2009): 3
# (751, 'CH6EA', 2016): 5
# (724, "'אוט 1800 CL ונטו", 1998): 1
# (676, '6Y5264', 2007): 4
# (650, 'GG4AL3G', 2002): 1
# (734, 'DM2', 2018): 5
# (817, 'VFAHHW-B2B01E', 2019): 2
# (724, '7EJ122', 2011): 3
# (253, 'DC51E', 2010): 2
# (735, 'CAYENNES 9PA', 2004): 1
# (727, '6V50K6', 2000): 1
# (650, 'SK9CY7L', 2021): 1
# (817, 'XSRHKH', 2011): 3
# (817, 'S1KFXF', 1998): 2
# (19, '4E205H', 2007): 2
# (743, '7N9HXC', 2012): 1
# (869, 'CF6R', 2008): 1
# (155, 'FD76', 2008): 4
# (683, 'FJB43V', 2005): 4
# (650, 'GC3DL5G', 1996): 2
# (481, 'G4EK ACCENT VA21N', 1999): 2
# (590, 'CX6ALTSPL6', 2013): 1
# (817, 'ACYHZR', 2019): 1
# (346, 'FK28', 2016): 5
# (885, 'MB7543', 2009): 2
# (676, 'NW43KD', 2020): 2
# (588, 'CP19S', 2003): 1
# (312, 'GD18', 2009): 2
# (177, '225AXG11', 2016): 2
# (19, '4F20NL', 2006): 1
# (885, 'D6814B', 2020): 2
# (676, '5E3434', 2015): 1
# (940, 'DZ1802', 2012): 1
# (941, 'RHYL 620 SI', 1999): 1
# (413, 'LN165L PRMSXW', 1999): 1
# (588, 'LW19G', 2002): 1
# (299, 'LYE21S', 2017): 2
# (413, 'GDJ150L-GKTEYW', 2020): 6
# (312, 'CL96', 2005): 2
# (885, 'FX411B', 2016): 5
# (928, 'CB1NOF', 2003): 1
# (734, 'DA3', 2011): 2
# (737, '199BXB11', 2009): 10
# (481, 'K381E', 2020): 2
# (590, 'CU5W', 2008): 2
# (590, 'CU5W', 2006): 4
# (650, 'GH2DL3S', 2011): 2
# (127, 'UBS73', 2000): 6
# (279, 'EFYHWC/E2E020', 2019): 1
# (288, 'TF48Y', 2000): 2
# (973, 'TFR86', 2008): 3
# (593, '205.004', 2017): 3
# (928, 'BG1PBA', 2007): 2
# (590, 'CX3ALTSHL6', 2009): 1
# (653, 'FBUK13', 2011): 3
# (637, 'FBAF15', 2013): 6
# (92, 'DM58W', 2002): 2
# (143, 'AL31', 1999): 1
# (724, '1K10E3', 2006): 6
# (712, 'N0B1T', 2014): 2
# (588, 'BK14Z', 2008): 1
# (312, 'GP18', 2013): 2
# (624, 'JCAT32', 2017): 8
# (743, 'DDBHY6', 2018): 1
# (734, 'DA3', 2008): 5
# (885, 'FH2213', 2013): 2
# (481, 'SH81B', 2011): 3
# (885, 'FE2223', 2006): 3
# (346, 'GG68', 2011): 2
# (19, '4LBOPL', 2008): 6
# (869, 'LB6R', 2004): 2
# (817, 'N1NFUN', 2003): 2
# (676, '545254', 2011): 1
# (650, 'GJ2RL1C', 2014): 4
# (739, '2HNFUB', 2007): 2
# (683, 'JTAA4V', 2010): 1
# (751, 'PJ8E8', 2016): 2
# (729, 'FDB6', 2008): 1
# (452, 'FN9EY', 2012): 2
# (590, 'N33WLRUEL6', 2001): 5
# (724, 'CD13LM', 2023): 1
# (21, '4L-4MB0F1', 2016): 2
# (724, 'AU-BQ13NZ', 2017): 2
# (676, 'TMBEHH673', 1999): 1
# (430, 'AZT220L-AEPEHW', 2003): 3
# (885, 'GE223', 2008): 1
# (299, 'LYD21S', 2017): 2
# (650, 'GP7ALRC', 2013): 1
# (481, 'CT41D', 2013): 3
# (778, '6J52E4', 2013): 2
# (990, '8VMCZG', 2018): 2
# (739, 'WCKFUC', 2008): 3
# (588, 'GG14F', 2004): 1
# (413, 'NCP20L-CHPNKW', 2006): 1
# (928, 'WK000', 2019): 1
# (288, 'JF696', 1999): 3
# (637, 'BCAP12', 2006): 2
# (941, 'LSAA', 2011): 3
# (351, 'B5220', 2020): 7
# (806, '447.703', 2023): 1
# (185, 'BCAC11', 2009): 4
# (634, 'KBNR20', 1999): 1
# (650, 'BLEBLLU', 2005): 1
# (481, 'VA21L', 1999): 1
# (683, 'GJB74V', 2019): 6
# (676, 'NS7RPZ', 2020): 1
# (676, '5J7SKC', 2009): 2
# (590, 'K96W', 2003): 2
# (430, 'ZWE211L-DHXNBW', 2021): 4
# (33, 'GX6EG', 2011): 1
# (885, 'EN2AA', 2023): 1
# (416, 'HM513G', 2018): 1
# (650, 'GH7BL5S', 2010): 1
# (676, '1Z33NC', 2007): 4
# (830, '292.324', 2017): 4
# (869, 'FF7W', 2009): 1
# (21, '4L-4MB0E1', 2017): 5
# (724, 'AU-5G12DZ', 2015): 4
# (940, 'RJB00', 2023): 2
# (724, '7HBS13', 2008): 2
# (722, 'ZW41', 2013): 2
# (19, 'B8-8W2CEG', 2016): 3
# (817, 'ACYHZS', 2021): 6
# (114, '204.007', 2009): 2
# (817, 'NC9HD7/1S', 2014): 1
# (413, 'ZRE151L-AEPNKW', 2009): 2
# (751, 'TM627', 2006): 2
# (676, '1U5173', 2006): 2
# (74, '955AXN1B', 2010): 2
# (724, '3572H7', 2010): 2
# (676, 'NU-NU73ND', 2021): 1
# (845, 'CM41C', 2006): 1
# (268, '8UGRWY', 2017): 2
# (776, 'FCC', 2014): 2
# (143, '2J51', 2019): 1
# (143, '318 I-4 CA91', 1997): 1
# (676, '6Y22F3', 2008): 1
# (590, 'CS9ASNHML6', 2006): 1
# (496, 'EFYHZR', 2021): 8
# (33, 'PD9EC', 2015): 6
# (481, 'DN41C', 2001): 1
# (787, 'CA27UR', 2022): 1
# (465, 'A13E', 2000): 2
# (724, '7HBX13', 2008): 6
# (676, '5E36SC', 2015): 2
# (724, '3H847T', 2022): 1
# (712, '26A1U', 2017): 1
# (940, 'LA1U05', 2003): 1
# (590, 'CX3ALTXPL6', 2010): 1
# (712, 'G09', 2006): 1
# (676, '3U43KB', 2006): 2
# (593, '205.040', 2018): 4
# (127, 'TFR69', 2000): 3
# (724, '7HB103', 2006): 4
# (739, '8BRFNR', 2003): 3
# (776, 'PJ2', 2008): 1
# (430, 'ZRT272L-AEXEPW', 2010): 2
# (730, 'DYB', 2013): 25
# (413, 'KZJ95L-GKPNTW', 1999): 2
# (676, '1Z33NC', 2006): 2
# (127, 'TFS69', 2001): 3
# (593, '205.040', 2014): 3
# (413, 'ACV30L-AEPNKW', 2006): 2
# (430, 'ZWE186L-DHXSBW', 2018): 4
# (751, 'TM627', 2007): 2
# (724, '1J2013', 2002): 1
# (940, 'BA0F02 RMG RT+1.6A', 1998): 1
# (672, 'ZKXZ-A7U000', 2023): 1
# (268, '8UGA8Y', 2018): 2
# (844, 'M240 CAE2AP', 2022): 1
# (771, '5RBU0D', 2019): 3
# (19, '8V1A6G', 2014): 5
# (388, 'MW66', 2009): 2
# (603, 'A13ASNHHL6', 2019): 1
# (593, '205.001', 2021): 2
# (724, '7HA172', 2010): 1
# (19, '4H80VA', 2012): 1
# (990, '8VMCZG', 2019): 2
# (33, 'SDL08', 2015): 1
# (624, 'PICKUP-DC', 2000): 1
# (413, 'LN165L PRMSXW', 2001): 1
# (588, 'BK12Z', 2005): 2
# (430, 'ZRT271L-AEXEPW', 2016): 3
# (588, 'DEA45', 2015): 1
# (288, 'TF69Y', 2001): 2
# (683, 'FTD32V', 1999): 2
# (588, 'GH12F', 2008): 2
# (885, 'FH2213', 2010): 3
# (751, 'JJ7E8', 2014): 3
# (481, 'KM81A', 2022): 3
# (177, '263WXD1B', 2013): 2
# (92, 'DM58W', 2003): 2
# (346, 'FK68', 2020): 2
# (776, 'PT2', 2008): 1
# (312, 'FD36', 2010): 1
# (751, 'UM92Z', 2007): 3
# (312, 'EK16', 1999): 5
# (869, 'B4HA', 2012): 1
# (322, 'B32S', 2017): 2
# (590, 'GF7WXTSXL6', 2015): 1
# (817, 'MFWJZF', 1999): 3
# (730, 'גרמניה FIESTA JAS', 1998): 3
# (481, 'JF21R', 1998): 6
# (739, '5FWJYF', 2002): 2
# (771, 'LZBR0A', 2009): 2
# (885, 'GEE2243', 2009): 1
# (739, 'M45GZW/C1F000', 2018): 5
# (593, 'A-190', 2000): 2
# (724, '7HB103', 2007): 5
# (940, 'LAOFOF RMG RN1.6', 1998): 1
# (751, 'JJ5EF', 2017): 1
# (715, '1K202C', 2008): 2
# (727, '6V20Z2', 1998): 1
# (603, 'CK4ASRMVL6U', 2001): 1
# (388, 'S70T LS56', 1998): 1
# (727, '6R12E7', 2014): 1
# (724, '1J21D3', 2005): 1
# (739, '2CKFXP', 2001): 3
# (737, '182AB11A', 2000): 1
# (590, 'N84WLRUCL6', 2003): 2
# (751, 'PJ9EY', 2014): 2
# (201, 'TT1O653', 1998): 1
# (778, '6J-6P11E2', 2016): 2
# (928, '1.9 DTI KCOUAF KAN', 2001): 1
# (724, '3B3165', 2003): 2
# (451, 'JC7E8', 2017): 5
# (724, '1K10E1', 2008): 2
# (885, 'JC5248', 2008): 3
# (771, 'RJA00', 2022): 7
# (143, 'HS71', 2016): 1
# (481, 'E3413', 2019): 2
# (724, '3B3165', 2001): 2
# (443, 'Z14E', 2016): 2
# (778, '1800 GTI איביזה', 1996): 1
# (869, 'JXAN', 2022): 1
# (413, 'LXH22L - SBSRXW', 2000): 1
# (730, 'JA8', 2010): 2
# (288, 'JA696', 2002): 3
# (361, 'CM59', 2005): 1
# (990, '8N3069', 2001): 1
# (588, 'CR19F', 2008): 3
# (650, 'GJ2CL1C', 2014): 2
# (143, 'GM21', 2005): 1
# (603, 'K74T', 2005): 4
# (127, 'TFS69', 1999): 2
# (734, 'DFW', 2002): 3
# (776, 'PU2', 2008): 1
# (312, 'FD15', 2008): 1
# (388, 'FS40', 2014): 5
# (676, '545254', 2013): 6
# (416, 'PC81BB', 2016): 3
# (388, 'MS66', 2005): 1
# (443, 'W740', 2020): 2
# (139, 'DJ6HV', 2015): 4
# (724, '1K100A', 2006): 2
# (603, 'KB4TNJNUZL6', 2010): 1
# (739, '2CKFXE', 2001): 2
# (253, 'J3813', 2018): 5
# (588, 'GL62M', 2022): 4
# (806, '639.703', 2014): 2
# (650, 'GF3HL3R', 2000): 2
# (404, 'ZWA10L-AHXBBW', 2012): 3
# (413, 'SXA11L-AWPGKW', 2000): 1
# (940, 'BB1LOF', 2002): 1
# (388, 'RS65', 2009): 2
# (941, 'GA2J', 2013): 2
# (869, 'EB6G', 2003): 1
# (715, '1K222K', 2010): 1
# (590, 'N33WLRUEL6', 2000): 5
# (299, 'NZC72', 2014): 5
# (19, '4B20CH', 2004): 2
# (650, 'BG5EL4R', 1998): 2
# (941, 'LMAM', 2004): 1
# (869, 'GP45R', 2006): 2
# (727, '9N31M4', 2009): 1
# (588, 'LANTIS-F-323 BJ14S', 2002): 1
# (724, '7EBX47', 2012): 2
# (739, '4BBFZ2', 1997): 1
# (940, '2R031A', 2019): 3
# (725, '2WJ19', 1996): 2
# (143, '318 I-4 CA91', 1996): 1
# (281, 'J102LG-JPXFW', 2002): 1
# (683, 'ERA31S', 2003): 4
# (312, 'ES56', 2002): 4
# (724, '3C-3G23JZ', 2017): 7
# (676, '545214', 2009): 1
# (751, 'JJ646', 2008): 3
# (771, '5RBU0D', 2017): 8
# (104, 'TGF48', 2001): 9
# (715, '1K22G5', 2010): 3
# (413, 'ZVW30L-AHXEBW', 2015): 3
# (778, '6K22T6', 2001): 1
# (624, 'CPGD22 PICKUP', 2003): 2
# (413, 'LN165L-PRMSXW', 2001): 1
# (413, 'KDJ90L-GJPNYW', 2002): 2
# (928, 'JM0UDA', 2005): 3
# (751, 'FC6EG', 2011): 1
# (907, '2E8N', 2003): 1
# (413, 'LN190L-PRPSXW', 2000): 1
# (676, '1U5273', 2002): 1
# (588, 'NC18F', 2007): 4
# (650, 'GJ2DLIC', 2015): 2
# (593, '212.003', 2010): 2
# (817, 'N2NFUN', 2001): 1
# (593, 'C220CDI', 2001): 1
# (724, 'AU-BQ12HZ', 2017): 2
# (845, 'CN41C', 2009): 1
# (82, '1379V3', 2011): 1
# (885, 'MB7543', 2008): 5
# (481, 'E34L1', 2016): 3
# (683, 'PFH11S', 2017): 4
# (724, '1T3224', 2015): 1
# (588, 'LANTIS LX AT BA126', 1997): 1
# (676, '5J-5422G4', 2013): 1
# (771, 'BR1BSA', 2010): 4
# (177, '225AXD11', 2014): 3
# (312, 'CL76', 2003): 4
# (724, '3B5358', 2000): 1
# (806, '639.815', 2013): 5
# (616, '164.120', 2008): 1
# (361, 'TS90', 2001): 2
# (727, '9K9BY1', 2001): 2
# (281, 'A101LS GPDE', 1999): 2
# (676, '5E33MD', 2016): 4
# (981, 'KB8R4', 2021): 2
# (650, 'GP3RLEC', 2015): 3
# (19, '8E20F4', 2002): 1
# (588, 'GJ627', 2015): 1
# (650, 'SK9CY6L', 2021): 1
# (644, 'F4Y', 2004): 1
# (103, 'SDL68', 2014): 3
# (940, '2RAU1D', 2015): 3
# (751, 'PJ9E8', 2018): 1
# (312, 'EK15', 1997): 3
# (676, 'NX-NX33LD', 2022): 3
# (624, 'CPUD22 PICKUP', 2003): 2
# (19, '8RB0NA', 2016): 2
# (74, '940FXB11', 2014): 9
# (281, 'J102LG-JMXFW', 2005): 1
# (941, 'LDVB', 2000): 1
# (739, '3ENFUF', 2007): 3
# (778, '5F15DZ', 2013): 1
# (737, '185BXE1A', 1998): 1
# (593, '253.946', 2017): 2
# (413, 'ZZE121L-AEPDKW', 2005): 2
# (724, '3B3134', 2004): 3
# (188, 'BD6EC', 2016): 2
# (19, '8E20HH', 2004): 2
# (776, 'FDC6', 2010): 2
# (346, 'RD88', 2006): 3
# (143, 'YH31', 2018): 1
# (676, '1Z32DD', 2012): 2
# (798, '312AXZ11', 2017): 2
# (513, '835EB54A', 1996): 1
# (33, 'PD9EC', 2018): 1
# (32, 'XM51', 2014): 2
# (143, '3X11', 2015): 3
# (544, '0SDCJ5', 2018): 3
# (724, '7EJ131', 2011): 3
# (650, 'ZC6BLE8', 2014): 1
# (928, 'KCTEEF', 2007): 1
# (968, 'ZCYHZ', 2020): 3
# (19, 'GABACG', 2017): 2
# (416, 'H4F19G', 2021): 1
# (973, 'TFR86', 2012): 3
# (739, '2ANFUB', 2009): 1
# (839, 'ZWE211L-DEXGBW', 2020): 4
# (650, 'BS9CLHC', 2017): 1
# (676, '6Y52F3', 2007): 3
# (676, '542464', 2008): 1
# (268, '8UB08Y', 2014): 5
# (413, 'KDN190L-PRPSYW', 2006): 2
# (139, 'DJ6HV', 2017): 8
# (413, 'AVA42L-ANXMBW', 2018): 3
# (152, '118.384', 2019): 4
# (593, '177.086', 2020): 5
# (973, 'TFR87', 2017): 3
# (771, 'LZLK0T', 2015): 4
# (593, '156.943', 2016): 5
# (82, '137RX3', 2013): 1
# (940, 'RJB00', 2021): 4
# (869, 'MP45R', 2004): 4
# (593, '906.633', 2014): 3
# (657, '450.432', 2005): 1
# (19, 'F53CSG', 2019): 1
# (650, 'BS9BLHC', 2016): 1
# (751, 'FC5ER', 2011): 2
# (283, 'FYBCAY', 2018): 9
# (143, '6D01', 2017): 1
# (634, 'JVWR51', 2007): 5
# (778, '5F55XX', 2015): 1
# (676, '5E34PD', 2015): 6
# (590, 'V98WLYHJL6', 2016): 5
# (724, '3B53E5', 1999): 1
# (603, 'KA4THJRUZL6', 2012): 3
# (771, '7R400E', 2014): 2
# (724, '3C-3G23JZ', 2016): 7
# (481, 'JM81V', 2009): 2
# (71, '1M28H3', 2001): 3
# (516, 'SH8FP0/1', 2013): 1
# (19, '8L1AA8', 2003): 2
# (739, '2MKFTO', 2011): 1
# (869, 'GP55R', 1999): 1
# (737, '185BXB1A', 1998): 2
# (593, '205.014', 2019): 2
# (899, 'GP54L', 2003): 2
# (885, 'DC2433', 2004): 1
# (737, '176AQ55P', 1996): 1
# (885, 'BX511A', 2014): 3
# (634, 'CVND40', 2008): 4
# (727, '9N30G4', 2006): 3
# (1207, '206046', 2023): 1
# (683, 'FDA32V', 2000): 1
# (413, 'KLH12L-SBSRHW', 2003): 2
# (771, 'LZBZ0L', 2013): 2
# (388, 'FS44', 2011): 3
# (430, 'ST220L-AEPEKW', 1999): 2
# (413, 'ZZE112L-AEPDKW', 2001): 1
# (962, '1WH19', 2001): 1
# (423, '5FP-KH74OZ', 2019): 1
# (413, 'ACM20L-ARSDKW', 2005): 1
# (731, 'D5KGMG', 1999): 1
# (413, 'LN165L-PRMSXW', 1998): 1
# (346, 'EP33', 2002): 1
# (778, 'דיזל 1900 טולדו', 1996): 1
# (388, 'V707 LW56', 1999): 1
# (481, 'ACCENT-VA21N', 1998): 2
# (650, 'BR5BL1C', 2011): 1
# (104, 'TGF48', 2000): 7
# (386, 'VS24', 2000): 2
# (724, '7DA1K3', 1999): 1
# (588, 'GJ523', 2014): 3
# (413, 'GRJ120L-GKAEKW', 2008): 5
# (798, '312AXA11', 2011): 3
# (496, '3EBHZT/2SM', 2017): 2
# (885, 'DEE2242', 2008): 1
# (590, 'V87W', 2007): 1
# (778, '5F168Y', 2017): 5
# (676, 'NS73LC', 2017): 4
# (724, '5K12E1', 2009): 2
# (778, '6K23F1', 2001): 1
# (593, '205.348', 2017): 4
# (650, 'SJ5BL7C', 2014): 1
# (676, 'NU74ND', 2021): 4
# (361, 'CM91', 2003): 1
# (724, '3B33P5', 2001): 1
# (312, 'CU26', 2011): 2
# (481, 'ST81B', 2015): 5
# (776, 'PT2', 2012): 1
# (481, 'BU51B', 2007): 4
# (637, 'FCAE11', 2007): 4
# (143, '1S11', 2017): 1
# (33, 'ZCF69', 2005): 9
# (715, '1C13D3', 2005): 1
# (21, '4LB0QA', 2010): 1
# (624, 'TBNT31', 2008): 2
# (940, '2R5A1H', 2013): 2
# (19, '8E20BH', 2003): 2
# (312, 'ZE28', 2010): 2
# (731, 'WA6', 2010): 2
# (551, '8X1ADG', 2013): 4
# (19, '8RB0RY', 2016): 2
# (481, 'JU81C', 2014): 1
# (715, '1622G5', 2014): 5
# (798, '312AXA11', 2018): 4
# (737, '182AB11A', 1997): 1
# (778, '5F15DZ', 2018): 4
# (676, 'NU74BD', 2018): 1
# (19, 'B8-8W2CEG', 2017): 3
# (481, 'WBX7K', 2015): 2
# (695, 'YS31', 2018): 1
# (737, '186AXCIA', 2008): 1
# (676, '1Z52DD', 2011): 2
# (840, 'KN9RS', 2022): 1
# (724, 'AU-5G12HZ', 2017): 2
# (739, '8ELFYP', 1999): 1
# (676, '5L7CDD', 2015): 2
# (676, '3V34ND', 2019): 3
# (404, 'GSE20L-AETLHW', 2011): 3
# (778, 'KJ75LZ', 2023): 2
# (739, 'WC5FWF', 2008): 3
# (177, '263WXD1B', 2017): 4
# (481, 'H-1 WWH7F', 1998): 1
# (593, '212.002', 2013): 2
# (590, 'NA4W', 2009): 3
# (188, 'PD6EC', 2011): 2
# (676, 'NU732D', 2018): 1
# (811, 'PSCFBC-W1C000', 2016): 2
# (481, 'טרגט MH81C', 2002): 1
# (114, '203.007', 2006): 1
# (481, 'MH81V', 2007): 4
# (973, 'TFR87', 2019): 3
# (114, 'S-320 LONG', 2002): 1
# (114, '203.046', 2007): 3
# (312, 'GK38', 2016): 3
# (237, 'CCHMZ0', 2015): 3
# (593, '222.178', 2016): 1
# (568, '4J5FU8', 2011): 1
# (481, 'EU41C', 2008): 2
# (885, 'FG5243', 2007): 1
# (590, 'CJ4AMRJEL6', 2000): 1
# (312, 'GD18', 2005): 3
# (806, '639.815', 2012): 4
# (817, 'NC5FS9/1', 2013): 2
# (19, '4G206Y', 2011): 2
# (650, 'BP5EL9S', 2008): 3
# (751, 'PJ6E8', 2016): 3
# (675, 'LTF00E', 2013): 2
# (634, 'TVUR20', 1999): 3
# (551, '8XFASG', 2018): 4
# (737, '199BXB1A', 2010): 2
# (817, 'DCRFNF', 2005): 2
# (624, 'TANZ50', 2007): 2
# (33, 'GM6ET', 2014): 1
# (481, 'DN41D', 2005): 1
# (683, 'EGC31S', 2002): 4
# (676, 'AADGEBX01', 2022): 1
# (724, '1K10E3', 2007): 7
# (676, '1U2274', 2001): 1
# (885, 'FH2213', 2012): 2
# (413, 'KZJ90L-GJPNTW', 1999): 2
# (928, 'FCOJAF KEX 1.9D RL', 2001): 1
# (724, '5N12T3', 2009): 1
# (676, 'NJ53ND', 2018): 1
# (590, 'GF7WXTXXL6', 2014): 5
# (840, 'DW677', 2005): 1
# (588, 'CR19F', 2009): 2
# (751, 'TJ62A', 2005): 2
# (817, 'DCRFNF', 2004): 3
# (885, 'JA5533', 2000): 1
# (683, 'EGC31W', 2001): 2
# (452, 'FN9E5', 2012): 1
# (155, 'ES76', 2004): 6
# (388, 'FS40', 2015): 7
# (624, 'BCAN15', 1997): 2
# (739, '3CRFNF', 2004): 3
# (940, 'RFE00', 2017): 8
# (177, '225AXC1A', 2017): 2
# (481, 'EN41F', 2004): 1
# (603, 'KK6TJLFFL6', 2021): 1
# (928, 'MASTER FDCCH5', 1999): 1
# (21, '4L-4MB0E1', 2015): 2
# (74, '940FXB11', 2013): 6
# (722, 'ZW41', 2012): 2
# (840, 'A95SX', 2018): 4
# (155, 'FC56', 2019): 3
# (465, 'A51M', 2008): 1
# (724, '1.8 CL גולף 1H12J3', 1997): 1
# (731, 'VAN TRANSIT 300S', 2003): 1
# (727, '6R-6C12EZ', 2016): 2
# (751, 'VJ54Z', 2006): 2
# (778, 'KJ14KZ', 2020): 1
# (496, 'GCWJYB', 2007): 4
# (885, 'FB2273', 2003): 2
# (281, 'אפלאוז-A101LS-GMDE', 1997): 5
# (940, 'BBOPOF', 2002): 1
# (299, 'NZC72', 2016): 6
# (312, 'EK16', 2000): 5
# (676, '5424KC', 2008): 2
# (683, 'EZC2IS', 2007): 2
# (928, 'JA04B5', 2001): 2
# (481, 'C851C', 2017): 2
# (941, 'CA2BN', 2017): 4
# (778, '6J15G7', 2011): 1
# (588, 'BM627', 2016): 9
# (739, '7BNFZP', 2001): 2
# (139, 'DEA25', 2010): 2
# (588, 'GG123', 2005): 1
# (496, 'MFWJYB', 2002): 9
# (590, 'CB4ASRDEQL6 לנסר', 1996): 1
# (588, 'BM52A', 2013): 2
# (885, 'DE2413', 2010): 1
# (724, '3C2196', 2008): 3
# (413, 'ZZE121L-AEPDKW', 2007): 4
# (416, 'PH81AB', 2016): 4
# (778, '6L15H4', 2007): 4
# (676, '1Z52GC', 2007): 2
# (928, 'KW25B5', 2013): 5
# (724, '1J11D3', 2002): 3
# (683, 'PFH11S', 2020): 2
# (155, 'FD76', 2010): 4
# (388, 'MS43B', 2010): 3
# (676, '5422G4', 2009): 1
# (737, '176AR55F', 1999): 3
# (19, '4B20SH', 2002): 1
# (817, 'RCRFJF', 2006): 3
# (727, '6N10C3', 2000): 1
# (981, 'AX9EV', 2018): 4
# (683, 'JTD54V', 2006): 3
# (590, 'ES5A גאלנט', 1996): 1
# (19, '8EC0EH', 2006): 1
# (676, '1Z526C', 2010): 1
# (590, 'V98WLYHJL6', 2012): 2
# (593, 'גג+_E250D מרצדס', 1998): 1
# (104, 'VECTRA-B-CC JBF68', 1998): 1
# (459, '7LAAC1', 2005): 2
# (739, '3CNFUF', 2006): 5
# (650, 'BL9ELHL', 2008): 5
# (388, 'RS53', 2002): 2
# (416, 'PK816H', 2017): 1
# (481, "ט'טרג MH81V", 2003): 1
# (885, 'PH813B', 2015): 4
# (481, 'ST81X', 2015): 4
# (676, '5J72JD', 2011): 1
# (724, '7HJ103', 2005): 4
# (676, '1Z3364', 2010): 2
# (941, 'RTZL', 2000): 1
# (817, 'RD5FVA', 2011): 2
# (637, 'JBNJ10', 2009): 3
# (481, 'SC81D', 2002): 1
# (19, 'GAGAZG', 2021): 2
# (731, 'WA6-S', 2015): 1
# (74, '952ACA2', 2021): 2
# (961, 'Z95ST', 2018): 2
# (751, 'JJ526', 2007): 2
# (724, '3B23J5', 1998): 1
# (798, '312AXF11', 2012): 2
# (516, 'SXHNPY', 2021): 4
# (650, 'BM5CLIC', 2012): 1
# (676, '1Z336C', 2010): 2
# (593, '204.048', 2010): 2
# (590, 'CB4WLNDEQL6', 1997): 1
# (845, 'CM41C', 2008): 2
# (676, '5422G4', 2012): 4
# (624, 'CAAN16', 2001): 1
# (143, 'NX51', 2008): 1
# (299, 'EXB32', 2011): 2
# (590, 'CX3ALTSPL6', 2011): 4
# (650, 'GT3BLFC', 2018): 1
# (590, 'V78W', 2001): 6
# (724, '3B23J5', 1997): 1
# (885, 'JA5533', 2002): 1
# (676, '1Z32GC', 2010): 2
# (590, 'N33WLRUEL6', 1996): 2
# (676, '545464', 2008): 2
# (739, '9UXFVJ', 2007): 1
# (481, 'DH41C', 2011): 4
# (143, 'PX31', 2008): 1
# (776, '350 L', 2006): 2
# (731, 'KOMBI TRANSIT 350L', 2004): 1
# (481, 'KPE1C  GALLOPER', 1999): 2
# (152, '117.343', 2019): 1
# (588, 'GG12F', 2004): 2
# (496, '7N9HXC', 2009): 2
# (928, 'JA04N5', 2000): 1
# (590, 'CS3ASRJEL6', 2004): 4
# (288, 'TA69Y', 1999): 2
# (143, 'HN61', 2008): 1
# (940, 'LAOFOF RMG RTA 1.6', 1999): 1
# (593, '212.056', 2009): 2
# (961, '1JC69', 2002): 1
# (739, '2AKFWR', 2002): 3
# (885, 'FA2422', 1998): 1
# (33, 'GM5ET', 2014): 1
# (413, 'KDN145L-PRMSYW', 2003): 1
# (739, '9D3FZE', 2001): 3
# (404, 'URJ150L-GKTZKA', 2020): 1
# (33, 'TGF35', 2002): 3
# (593, 'C 200', 1999): 1
# (737, '199BXB1A', 2011): 4
# (588, 'BN62A', 2018): 2
# (281, 'אפלאוז-A101LS-GHDE', 1996): 1
# (940, '2R401E', 2014): 4
# (845, 'A751A', 2014): 4
# (416, 'FF5243', 2009): 3
# (739, '7BWJZT', 2000): 2
# (143, '8A11', 2017): 2
# (588, 'BN627', 2019): 3
# (481, 'BU51D', 2006): 2
# (33, 'PD9EC', 2012): 2
# (19, '8P1S49', 2008): 1
# (724, '5N12T3', 2010): 2
# (644, 'ED4', 2000): 2
# (413, 'AXAL52L-ANXMBW', 2022): 4
# (839, 'ZWE211L-DEXGBW', 2019): 4
# (388, 'LS61', 2000): 2
# (143, '8A11', 2015): 1
# (481, 'HN61F', 2006): 2
# (650, 'SG5FL2E', 2008): 3
# (676, '3T42LD', 2009): 3
# (739, '1ANFZT', 1997): 1
# (481, 'ST81X', 2016): 2
# (481, 'SC81D', 2003): 1
# (413, 'ZVW40L-AWXEBW', 2021): 1
# (885, 'CB81CG', 2019): 2
# (312, 'EK15', 1996): 3
# (481, 'RC813', 2020): 3
# (839, 'ZWE211L-DEXNBW', 2021): 21
# (413, 'KLH22L-SBSRHW', 2003): 2
# (811, 'PSCFBB-H1C000', 2016): 1
# (650, 'GJ2RL1C', 2015): 4
# (603, 'KL1TJYUFL6', 2019): 1
# (481, 'S381D', 2019): 2
# (301, '2K-SAJT26', 2019): 2
# (19, '8D20H4', 2001): 1
# (724, '7HJ103', 2008): 4
# (973, 'TFR86', 2015): 5
# (590, 'GF7WXTXXL6', 2018): 6
# (650, 'SG5CL1R', 2005): 2
# (724, '3B23C5', 1999): 1
# (351, 'HSDJ9F', 2016): 2
# (481, 'CF31G', 2002): 4
# (990, 'F3NAZG', 2022): 6
# (481, 'JT81V', 2013): 2
# (1229, 'SA7E', 2022): 3
# (416, 'H4F14G', 2021): 1
# (139, 'UN8F3', 2000): 1
# (676, '3T-3V33QD', 2022): 1
# (496, 'EFYHZR/E2F020', 2019): 4
# (74, '936A1001', 1999): 1
# (21, '4LB0GA', 2012): 2
# (404, 'ZWA10L-AHXBBW', 2014): 3
# (941, 'LTGM', 2001): 7
# (869, 'JFAG', 2019): 5
# (593, '213.053', 2021): 9
# (19, '4B206H', 2004): 2
# (143, 'GJ01', 1999): 1
# (839, 'ZYX10L-AHXGBW', 2019): 7
# (739, 'CUHNPN/S', 2019): 1
# (981, 'B85SM', 2018): 4
# (490, 'KGB40L-AHGGKW', 2019): 3
# (724, '1J2034', 2004): 2
# (817, 'S0KFXF', 1998): 2
# (593, '3G8GB6', 2023): 1
# (817, 'N2L900', 1997): 1
# (724, 'AU-BQ19UY', 2018): 4
# (413, 'GDJ150L-GKTEYW', 2018): 11
# (103, 'SBF68', 2000): 8
# (962, '175S3', 2014): 4
# (724, '1J16R4', 2000): 2
# (676, '1U2274', 2004): 3
# (481, 'WVH7H', 2004): 2
# (739, '8BRHZR', 2004): 1
# (676, '5E34PD', 2014): 5
# (19, '4GC08G', 2018): 1
# (925, 'FB631', 2000): 1
# (676, '1U2273', 2004): 4
# (739, '7BDHYE', 2000): 1
# (637, 'TBAE12', 2016): 2
# (74, '937CXH11', 2009): 1
# (19, '4BH0FZ', 2004): 1
# (676, '3V348D', 2018): 3
# (143, '323 I-2 A BF81', 1998): 1
# (724, '1J2274', 2000): 1
# (459, 'AA-1213DW', 2015): 2
# (676, '5E333D', 2015): 2
# (388, 'DZ70', 2010): 3
# (724, '1J11G3', 2001): 3
# (686, 'NHP130L-CHXNBW', 2017): 1
# (19, '4B207Z', 2002): 1
# (644, '9000CD', 1996): 1
# (588, 'BP6S7', 2022): 6
# (143, '5P51', 2023): 1
# (413, 'ZRE151L-AEMNKW', 2009): 1
# (143, 'AT51', 2003): 2
# (114, '230.467', 2004): 1
# (143, '528 IA DD61', 1996): 1
# (590, 'GF7WXTXXL6', 2020): 6
# (737, '230BDMFB', 1998): 2
# (672, 'MDZ642L-LBADGW', 2017): 2
# (940, 'JLB7AA', 2012): 1
# (724, '5K12G5', 2010): 2
# (973, 'TFR87', 2020): 2
# (490, 'KGB40L-AHGGKW', 2016): 4
# (734, 'DM2', 2013): 4
# (74, '932A1001', 2001): 2
# (739, '4ELFZ4', 1997): 1
# (724, '52122K', 2013): 1
# (724, '3D25B7', 2005): 1
# (817, 'KF5FVA', 2013): 2
# (281, 'A101LS-GMME', 1998): 1
# (459, '7P520J', 2011): 3
# (817, 'SC5FS9/1', 2010): 3
# (32, 'MF71', 2008): 3
# (961, 'CV14526', 2014): 4
# (817, 'N1WJYB', 2003): 1
# (928, 'B57BK1 CLIO RN2 AT', 1996): 1
# (19, "'אוט 1600 A4 אודי", 1997): 1
# (19, '8L1B9K', 2001): 2
# (650, 'GP3ELEC', 2016): 4
# (413, 'USF40L-AEZGHW', 2008): 2
# (739, '6D3FYF', 2008): 2
# (188, 'PD6EC', 2015): 6
# (335, 'GJKFWC', 2008): 1
# (734, 'DAW', 2000): 1
# (413, 'GDJ155L-GJTEYW', 2022): 1
# (588, 'MPV-LV12J', 1999): 1
# (778, '6L12E4', 2008): 2
# (676, '5E33DD', 2013): 2
# (855, 'YB8B', 2006): 1
# (33, 'ZCF69', 2003): 5
# (869, 'MB6H', 2000): 1
# (839, 'ZRE181L-DEXNPW', 2013): 2
# (737, '199BXB11', 2012): 6
# (416, 'HN516G', 2016): 2
# (683, 'FJB43V', 2008): 4
# (704, 'AA-NF13A1', 2016): 2
# (724, '7DK2Y5', 2003): 1
# (310, '2AKFWA', 2007): 2
# (778, '6K3ALM2', 1999): 1
# (676, '1Z3264', 2008): 7
# (676, '5422KC', 2010): 1
# (830, '292.324', 2018): 3
# (590, 'CW5WXTHHZL6', 2010): 2
# (312, 'EK16', 1998): 4
# (481, 'DN41D', 2007): 2
# (724, '7HB142', 2007): 3
# (650, 'GDCGL1E', 2007): 9
# (961, '3NL69', 2001): 2
# (676, '1Z336C', 2009): 2
# (404, 'AVE30L-AEXLHW', 2019): 3
# (751, 'JJ526', 2005): 3
# (104, 'TGF48', 2002): 10
# (928, 'KW2UBA', 2013): 5
# (676, '1Z526C', 2009): 2
# (722, 'CV61', 2019): 1
# (885, 'UP7523', 2002): 1
# (650, 'BD2EL4R', 1998): 3
# (885, 'GE2273', 2009): 1
# (676, '5E34MD', 2015): 2
# (301, '2CBS82', 2013): 2
# (312, 'EK16', 1997): 3
# (727, '9N30M7', 2008): 4
# (19, '8K202H', 2009): 2
# (481, 'S381D', 2020): 2
# (798, '312AXA11', 2019): 5
# (729, 'FAA6', 2010): 1
# (299, 'JYA22', 2016): 4
# (751, 'DC53R', 2009): 2
# (650, 'GDFFLEH', 2006): 1
# (590, 'V78W', 2002): 6
# (650, 'GP7ELUC', 2016): 4
# (32, 'SU31', 2011): 2
# (885, 'DA2423', 1997): 1
# (416, 'HC812B', 2010): 1
# (734, 'DFW', 2004): 4
# (885, 'DE2413', 2011): 1
# (676, '1U2274', 2000): 1
# (33, 'VBM69', 2002): 2
# (590, 'EA2ASRHEQL6', 1997): 2
# (683, 'EGC31S', 2000): 4
# (885, 'DN412B', 2017): 2
# (588, 'KEC97', 2014): 2
# (459, '7LAAM1', 2007): 5
# (443, 'W74C', 2019): 3
# (778, '6J82J7', 2013): 3
# (634, 'AEVC23', 1998): 1
# (496, 'CHRFNF', 2006): 1
# (885, 'PC811D', 2011): 1
# (724, '7HJX13', 2008): 2
# (676, '1Z339C', 2012): 2
# (590, 'CJ4AMRJEL6', 2002): 1
# (885, 'FX411B', 2014): 9
# (672, 'NHP130L-CHXNBW', 2018): 5
# (380, 'LFE42S', 2019): 2
# (928, 'KCOJEF KAN AU', 2004): 1
# (676, '5E33MD', 2017): 5
# (624, 'BCAN15 ALMERA GX A', 1999): 1
# (281, 'G200LS-GPDE', 1999): 2
# (724, '3623H7', 2013): 2
# (869, 'BG8B', 2008): 2
# (724, '1J21G3', 2001): 1
# (634, 'CVND40', 2007): 7
# (416, 'HM816A', 2016): 2
# (928, 'JM1R0A', 2009): 2
# (593, '253.954', 2017): 1
# (76, 'PD8EC', 2014): 4
# (676, '6Y22J4', 2006): 4
# (676, '5E34FD', 2016): 7
# (624, 'BCAN15 ALMERA GX', 1997): 1
# (70, 'BT26', 2004): 2
# (778, '5F12OZ', 2019): 3
# (697, 'AA-KF13D1', 2013): 2
# (735, '992', 2023): 1
# (940, 'BM1R0A', 2007): 9
# (413, 'ZZE121L-AEMNKW', 2007): 1
# (513, '838AC1AA', 1998): 1
# (177, '223WXLIA', 2009): 1
# (143, '41AW', 2024): 1
# (361, 'AS56', 2007): 2
# (185, 'FCAC11', 2009): 3
# (676, '6Y3224', 2006): 3
# (588, 'BK14Z', 2006): 1
# (19, '4B20TZ', 2001): 1
# (885, 'CC81CG', 2017): 1
# (430, 'ZZE121L-DHPNKW', 2003): 2
# (751, 'CM6EA', 2016): 6
# (413, 'ZRE151L-AEFNKW', 2010): 1
# (19, '4D2G6K', 1999): 1
# (403, 'PAHMTC/H1A000', 2016): 1
# (488, 'AXVH71L-CEXGBA', 2019): 1
# (634, 'DEVC23', 2002): 1
# (413, 'SXA11L - AWPGKW', 1997): 1
# (496, 'GJWJYB', 2003): 2
# (724, '3B31D4', 2002): 3
# (817, 'X1RFVM', 2001): 1
# (496, 'UA5FXH', 2009): 3
# (739, '3HNFUE', 2004): 1
# (481, 'CT41C', 2011): 1
# (650, 'GG4AL3R', 2001): 1
# (961, '1ZH69', 2008): 3
# (637, 'FBAJ10', 2008): 4
# (885, 'DN511A', 2012): 1
# (19, '8K201H', 2010): 2
# (143, '71DY', 2021): 2
# (288, 'TF69Y', 1998): 2
# (776, 'PT2', 2010): 1
# (715, '1622D5', 2012): 2
# (481, 'HN61D', 2005): 1
# (961, 'Z95E1', 2011): 3
# (676, '614', 2000): 2
# (416, 'PC811B', 2014): 2
# (751, 'PM55', 2011): 3
# (724, '3C20J7', 2010): 1
# (676, '3T43LD', 2012): 1
# (928, 'KCOEAF KAN', 2000): 2
# (940, 'BA0F02 RMG RT 1.6A', 1996): 1
# (413, 'KDN190L-PRPSYW', 2004): 1
# (940, 'BA0F0D RMG RT 1.6', 1997): 1
# (637, 'FBAN16', 2005): 1
# (188, 'PD5EC', 2014): 3
# (593, '204.001', 2011): 2
# (634, 'JVWR51', 2008): 3
# (724, '3B31D4', 2004): 4
# (653, 'FBUK13', 2016): 4
# (778, '6L23C4', 2008): 2
# (513, '835FG54A', 1997): 1
# (885, 'JT815B', 2014): 2
# (940, 'LA0W05', 2001): 1
# (885, 'PC811D', 2012): 1
# (722, 'X5 3.OD FA71', 2002): 1
# (588, 'GL627', 2018): 2
# (751, 'UM92Z', 2005): 3
# (683, 'ERA31S', 2006): 9
# (724, '1J11C4', 2001): 3
# (676, '1Z33MD', 2012): 2
# (299, 'MAB35S', 2000): 2
# (676, 'NW43JD', 2021): 1
# (806, '447.703', 2017): 1
# (817, 'NC5FS9/1', 2012): 2
# (778, '6J-6P12KZ', 2017): 3
# (268, 'GBAANG', 2019): 3
# (724, '7HJ101', 2008): 3
# (676, '5452F4', 2010): 2
# (863, 'KUN15L-PRMDYW', 2007): 2
# (281, 'אפלאוז-A101LS-GHDE', 1997): 5
# (771, 'LZLF0E', 2015): 12
# (676, '3T439C', 2011): 2
# (481, 'EM41B', 2001): 1
# (715, '162225', 2011): 1
# (33, 'TGF35', 2000): 4
# (312, 'GK38', 2019): 7
# (388, 'RS61', 2002): 2
# (778, '6J55G4', 2011): 1
# (593, 'C200', 1998): 1
# (734, 'DB3', 2007): 6
# (811, 'PNCFB4', 2011): 1
# (928, 'FDCUM5', 2004): 1
# (288, 'TF69Y', 2000): 2
# (481, 'CT41D', 2017): 2
# (778, 'KJ72KZ', 2019): 3
# (481, 'H-1 YKN7H', 2005): 1
# (676, '1U2154', 2008): 7
# (778, '5F55DZ', 2015): 1
# (413, 'ZVG12L-KHXGBW', 2023): 2
# (388, 'S 70 GLE', 1998): 1
# (588, 'BJ12M', 2003): 2
# (177, '255AXD11', 2014): 1
# (751, 'JJ546', 2007): 4
# (650, 'GD4AL3G', 2001): 1
# (19, '4B202H', 2002): 1
# (299, 'NZC72', 2015): 9
# (518, '179BXF11', 2004): 2
# (590, 'K94W', 2000): 2
# (730, 'JA8', 2013): 8
# (737, '199BXB11', 2010): 7
# (776, 'FDC6', 2009): 1
# (481, 'TC61D', 2011): 4
# (676, '6Y32J4', 2002): 1
# (481, 'EU41C', 2007): 4
# (281, 'J100LG-GPXEW', 2000): 4
# (973, 'TFR 86', 2011): 1
# (413, 'KDN190L-PRPSYW', 2005): 1
# (423, 'KG34PD', 2013): 2
# (727, '6R13F7', 2014): 2
# (676, '1Z333C', 2012): 2
# (727, '6N20U4', 2000): 1
# (19, '8PAABG', 2012): 3
# (74, '940FXB11', 2016): 14
# (739, '1AKFXT', 1999): 1
# (771, 'LZVM0H', 2016): 2
# (1236, 'U5-PREMIUM', 2021): 1
# (634, 'YBAM20', 2016): 3
# (676, '6Y21D4', 2002): 1
# (739, '2AKFXE', 1999): 3
# (845, 'WWH7H', 2004): 2
# (778, '5F124Z', 2018): 2
# (798, '312AXA11', 2015): 7
# (443, 'W74C', 2020): 1
# (481, 'JN81V', 2006): 3
# (253, 'D281C', 2015): 3
# (74, '937CXH1A', 2008): 1
# (731, 'B4Y', 2005): 1
# (650, 'BL5BL4L', 2005): 2
# (413, 'ZRE151L-AEGNKW', 2008): 3
# (603, 'KA4THJNUZL6', 2013): 2
# (177, '356SXE11', 2016): 2
# (724, '1T2HB3', 2008): 1
# (143, 'WA51', 2008): 1
# (299, 'JYAA2', 2018): 2
# (739, '3CRFJF', 2007): 3
# (413, 'AXAL52L-ANXMBW', 2021): 3
# (676, '1Z32LD', 2010): 1
# (737, '176AQ55F', 1997): 1
# (637, 'FBAN16', 2004): 1
# (798, '169AXB1A', 2009): 2
# (724, '1K10H3', 2006): 4
# (940, 'BA0F02 RMG RT+1.6A', 1999): 1
# (312, 'GE68', 2012): 1
# (413, 'ACV40L-AEANKW', 2007): 4
# (590, 'GF7WXTXXL6', 2021): 4
# (676, '5423K4', 2008): 2
# (727, '6N20Q3', 2001): 1
# (155, 'ES76', 2005): 6
# (727, '9N10G4', 2003): 2
# (288, 'NUBIRA-JF486', 1998): 1
# (817, 'צד דלת SUP MFWJZF', 1999): 1
# (961, '1ZH69', 2010): 6
# (940, 'KZ490J', 2015): 2
# (928, 'KC1EVF', 2008): 1
# (312, 'CU16', 2011): 5
# (751, 'VJ54Z', 2005): 3
# (19, '8E20AH', 2005): 2
# (751, 'CM6EA', 2018): 5
# (650, 'BR9DLK9', 2013): 1
# (771, 'LM1R0A', 2007): 5
# (590, 'CY1ASRSPL6', 2012): 3
# (751, 'JM5EE', 2012): 2
# (885, 'GN414B', 2012): 2
# (751, 'CJ6ED', 2011): 2
# (33, 'JBF19', 2001): 3
# (869, 'SH41', 2009): 4
# (798, '312AXD1A', 2010): 3
# (413, 'GRJ125L-GJAEKW', 2008): 3
# (650, 'SJ5DL2C', 2016): 1
# (845, 'BN51G', 2023): 6
# (481, 'H-1 YKN7H', 2007): 2
# (104, 'TGF48', 1999): 5
# (481, 'BU51B', 2006): 3
# (724, '1J11G4', 2001): 3
# (727, '6N10F4', 1999): 1
# (430, 'ZWE211L-DWXNBW', 2021): 4
# (634, 'CVAD40', 2007): 2
# (268, '8UGA8Y', 2017): 3
# (496, '7JBHY6/3', 2016): 2
# (724, '3B2358', 2001): 1
# (74, '940FXB11', 2011): 4
# (588, '323F LANTIS-BA14P', 1997): 1
# (590, 'CS3ASRJEL6', 2006): 7
# (603, 'K74TL', 2001): 1
# (588, 'GHA2L', 2010): 2
# (817, 'S1KFXD', 2001): 1
# (737, '230CLMAC', 2000): 1
# (845, 'CM41A', 2007): 4
# (730, 'אנגליה_JAS פיאסטה', 1997): 3
# (940, 'LAOFOF RMG RT1.6', 1997): 1
# (724, '7DK2K3', 2001): 1
# (413, 'ACM20L-ARSDKW', 2004): 1
# (143, 'NA71', 2004): 2
# (676, '6Y32D4', 2003): 1
# (177, '223AXF1A', 2005): 4
# (413, 'LN145L - PRMDSW', 1998): 1
# (19, '8E2ONH', 2004): 1
# (481, 'DB51D', 2009): 1
# (650, 'GC3DL3R', 1996): 3
# (590, 'GM4WXTXCL2B', 2021): 3
# (739, '5FD9BD', 1999): 2
# (941, 'RJSL', 2000): 1
# (724, '1J1004', 2004): 2
# (724, '3C2146', 2006): 3
# (724, '3574K6', 2011): 1
# (778, '6J15G4', 2011): 2
# (588, 'DE145', 2010): 2
# (727, '9N11G4', 2003): 2
# (940, 'FLBCD6', 2005): 2
# (798, '169AXB1A', 2010): 1
# (737, '185AXE1A', 1998): 1
# (653, 'FBUK13', 2018): 2
# (839, 'ZYX10L-AHXNBW', 2018): 7
# (19, '8PAAIG', 2011): 2
# (322, 'GFC31S', 2014): 4
# (817, 'BEDHXA', 1999): 1
# (143, '523 IA DD41', 1997): 1
# (103, 'SDL68', 2008): 4
# (637, 'FBAN16', 2006): 2
# (885, 'D6811G', 2020): 3
# (845, 'A751A', 2015): 7
# (413, 'ACA30L-AWPXKW', 2007): 2
# (590, 'V98WLYHJL6', 2015): 5
# (416, 'PG812G', 2019): 2
# (739, '2HNFUF', 2002): 2
# (281, 'J100LG-GPXEW', 1999): 2
# (751, 'JJ5D6', 2010): 1
# (637, 'FBAJ10', 2010): 8
# (593, '246.201', 2014): 2
# (139, 'UN1F3', 2000): 1
# (650, 'SJ5BL2C', 2015): 2
# (502, 'BB51C', 2009): 3
# (676, 'NS74PZ', 2019): 3
# (152, '117.343', 2013): 2
# (413, 'ZRE151L-AEGDKW', 2008): 1
# (771, 'LB0PCA CL2', 2006): 1
# (322, 'B32S', 2016): 2
# (590, 'CS3ASRJEL6', 2009): 2
# (724, '1J12J4', 1999): 2
# (322, 'B32S', 2018): 2
# (724, '7DK2K2', 2000): 1
# (751, 'CH6EA', 2018): 3
# (74, '952ABA2', 2021): 3
# (413, 'KDJ120L-GKAEYW', 2008): 10
# (139, 'DJ6HV', 2018): 4
# (288, 'JA486', 2001): 1
# (724, '3C-36235Y', 2013): 1
# (844, 'M156 7F25W', 2019): 1
# (724, '7DA1U2', 2003): 1
# (940, 'LA0A0E RMG RND1.9D', 1999): 1
# (388, 'MV48', 2015): 4
# (928, 'JA0F02', 1999): 2
# (676, 'NH33RD', 2017): 3
# (590, 'GA2WXTMHL2B', 2022): 3
# (588, 'NC18F', 2008): 1
# (727, '6R-6C13EZ', 2014): 2
# (739, '20AHD2', 1997): 2
# (724, '7EA112', 2011): 2
# (941, 'LAAA', 2006): 4
# (724, '1J20C3', 2001): 2
# (650, 'SHGBLHS', 2010): 1
# (961, 'F91RS', 2020): 1
# (899, 'TOWN COUNTRY MP44R', 2001): 1
# (33, 'SDL08', 2012): 3
# (114, 'L0NG A 190', 2003): 1
# (588, '626-GE14J', 1996): 1
# (19, '4F20WL', 2009): 2
# (676, '5J72G4', 2012): 1
# (650, 'GT3RLFC', 2019): 1
# (724, '3B61D4', 2002): 1
# (19, '8P1A6G', 2009): 2
# (430, 'AZT250L-AEPEHW', 2006): 2
# (593, 'E 240', 2000): 2
# ...
# {'_id': 30937, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 1810, 'degem_nm': 'N1DHYF', 'shnat_yitzur': 1998, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 509, 'kinuy_mishari': 'XSARA', 'supply_index': 1}
# {'_id': 30943, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 2, 'degem_nm': 'XSAHZ8', 'shnat_yitzur': 2015, 'mispar_rechavim_pailim': 263, 'mispar_rechavim_le_pailim': 49, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 30983, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 4200, 'degem_nm': 'MFWJYB', 'shnat_yitzur': 2001, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 11, 'kinuy_mishari': 'BERLINGO', 'supply_index': 2}
# {'_id': 30991, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 591, 'degem_nm': 'SA5FS9/1', 'shnat_yitzur': 2010, 'mispar_rechavim_pailim': 6, 'mispar_rechavim_le_pailim': 4, 'kinuy_mishari': 'DS3', 'supply_index': 1}
# {'_id': 30997, 'sug_degem': 'P', 'tozeret_cd': 516, 'tozeret_nm': 'סיטרואן סלובק', 'tozeret_eretz_nm': 'סלובקיה', 'tozar': 'סיטרואן', 'degem_cd': 30, 'degem_nm': 'SH8FP0/1', 'shnat_yitzur': 2011, 'mispar_rechavim_pailim': 6, 'mispar_rechavim_le_pailim': 8, 'kinuy_mishari': 'C3 PICASS0', 'supply_index': 1}
# {'_id': 30999, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 176, 'degem_nm': 'BBYHZB', 'shnat_yitzur': 2023, 'mispar_rechavim_pailim': 44, 'mispar_rechavim_le_pailim': 2, 'kinuy_mishari': 'C4', 'supply_index': 2}
# {'_id': 31015, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 58, 'degem_nm': 'VFAHHW-B2B01B', 'shnat_yitzur': 2017, 'mispar_rechavim_pailim': 32, 'mispar_rechavim_le_pailim': 7, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 31027, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 301, 'degem_nm': 'DCXFXF', 'shnat_yitzur': 2004, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 7, 'kinuy_mishari': 'C5', 'supply_index': 2}
# {'_id': 31092, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 107, 'degem_nm': '2RHNZW/R1B000', 'shnat_yitzur': 2018, 'mispar_rechavim_pailim': 82, 'mispar_rechavim_le_pailim': 4, 'kinuy_mishari': 'C3 AIRCROSS', 'supply_index': 1}
# {'_id': 31130, 'sug_degem': 'M', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 59, 'degem_nm': 'EFYHYC', 'shnat_yitzur': 2019, 'mispar_rechavim_pailim': 9, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'BERLINGO', 'supply_index': 1}
# {'_id': 31141, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 83, 'degem_nm': 'VFEHZ8', 'shnat_yitzur': 2020, 'mispar_rechavim_pailim': 33, 'mispar_rechavim_le_pailim': 2, 'kinuy_mishari': 'JUMPY', 'supply_index': 4}
# {'_id': 31169, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 55, 'degem_nm': 'KF5FVA', 'shnat_yitzur': 2014, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'DS5', 'supply_index': 3}
# {'_id': 31197, 'sug_degem': 'P', 'tozeret_cd': 862, 'tozeret_nm': 'סיטרואן תורכיה', 'tozeret_eretz_nm': 'תורכיה', 'tozar': 'סיטרואן', 'degem_cd': 2, 'degem_nm': 'AJFHZ0/PSH', 'shnat_yitzur': 2013, 'mispar_rechavim_pailim': 34, 'mispar_rechavim_le_pailim': 71, 'kinuy_mishari': 'NEMO', 'supply_index': 1}
# {'_id': 31236, 'sug_degem': 'M', 'tozeret_cd': 279, 'tozeret_nm': 'סיטרואן פורטוג', 'tozeret_eretz_nm': 'פורטוגל', 'tozar': 'סיטרואן', 'degem_cd': 22, 'degem_nm': 'EFYHZR', 'shnat_yitzur': 2021, 'mispar_rechavim_pailim': 480, 'mispar_rechavim_le_pailim': 23, 'kinuy_mishari': 'BERLINGO', 'supply_index': 5}
# {'_id': 31237, 'sug_degem': 'M', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 3, 'degem_nm': '7F9HF0', 'shnat_yitzur': 2013, 'mispar_rechavim_pailim': 126, 'mispar_rechavim_le_pailim': 38, 'kinuy_mishari': 'BERLINGO', 'supply_index': 2}
# {'_id': 31260, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 41, 'degem_nm': 'DCRHZE', 'shnat_yitzur': 2002, 'mispar_rechavim_pailim': 1, 'mispar_rechavim_le_pailim': 83, 'kinuy_mishari': 'C5', 'supply_index': 2}
# {'_id': 31263, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 2, 'degem_nm': 'XSAHZ8', 'shnat_yitzur': 2014, 'mispar_rechavim_pailim': 93, 'mispar_rechavim_le_pailim': 24, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 31301, 'sug_degem': 'P', 'tozeret_cd': 811, 'tozeret_nm': "סיטרואן צ'כיה", 'tozeret_eretz_nm': "צ'כיה", 'tozar': 'סיטרואן', 'degem_cd': 9, 'degem_nm': 'PSCFBC-H1C000', 'shnat_yitzur': 2015, 'mispar_rechavim_pailim': 63, 'mispar_rechavim_le_pailim': 9, 'kinuy_mishari': 'C1', 'supply_index': 1}
# {'_id': 31302, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 60, 'degem_nm': 'GJRHYK', 'shnat_yitzur': 2004, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 5, 'kinuy_mishari': 'BERLINGO', 'supply_index': 4}
# {'_id': 31321, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 17, 'degem_nm': 'SA5FS9/1', 'shnat_yitzur': 2014, 'mispar_rechavim_pailim': 15, 'mispar_rechavim_le_pailim': 2, 'kinuy_mishari': 'DS3', 'supply_index': 2}
# {'_id': 31336, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 241, 'degem_nm': 'FCKFVE', 'shnat_yitzur': 2003, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 7, 'kinuy_mishari': 'C3', 'supply_index': 4}
# {'_id': 31353, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 1240, 'degem_nm': 'N1RHYB', 'shnat_yitzur': 2005, 'mispar_rechavim_pailim': 3, 'mispar_rechavim_le_pailim': 7, 'kinuy_mishari': 'XSARA 2', 'supply_index': 1}
# {'_id': 31354, 'sug_degem': 'M', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 20, 'degem_nm': 'GJ9HXC', 'shnat_yitzur': 2007, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 5, 'kinuy_mishari': 'BERLINGO', 'supply_index': 5}
# {'_id': 31373, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 2080, 'degem_nm': 'N2C300', 'shnat_yitzur': 1997, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': "D 9.1XSXZ_5דלת'", 'supply_index': 4}
# {'_id': 31383, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 79, 'degem_nm': 'VBYHVK', 'shnat_yitzur': 2019, 'mispar_rechavim_pailim': 3, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 31390, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 206, 'degem_nm': 'BBYHZB', 'shnat_yitzur': 2023, 'mispar_rechavim_pailim': 64, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'C4', 'supply_index': 2}
# {'_id': 31391, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 1531, 'degem_nm': 'X1LFYM', 'shnat_yitzur': 1998, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': "8.1 TNAX 5דל'", 'supply_index': 1}
# {'_id': 31392, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 80, 'degem_nm': 'GJRHYK', 'shnat_yitzur': 2004, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'BERLINGO', 'supply_index': 4}
# {'_id': 31428, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 300, 'degem_nm': 'S1HFXB', 'shnat_yitzur': 2001, 'mispar_rechavim_pailim': 1, 'mispar_rechavim_le_pailim': 72, 'kinuy_mishari': 'SAXO', 'supply_index': 1}
# {'_id': 31445, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 41, 'degem_nm': 'UARFJF', 'shnat_yitzur': 2008, 'mispar_rechavim_pailim': 37, 'mispar_rechavim_le_pailim': 63, 'kinuy_mishari': 'C4 PICASSO', 'supply_index': 4}
# {'_id': 31446, 'sug_degem': 'P', 'tozeret_cd': 516, 'tozeret_nm': 'סיטרואן סלובק', 'tozeret_eretz_nm': 'סלובקיה', 'tozar': 'סיטרואן', 'degem_cd': 1, 'degem_nm': 'SH9HP8/1PS', 'shnat_yitzur': 2012, 'mispar_rechavim_pailim': 147, 'mispar_rechavim_le_pailim': 145, 'kinuy_mishari': 'C3 PICASSO', 'supply_index': 1}
# {'_id': 31475, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 1730, 'degem_nm': 'S1HDZF', 'shnat_yitzur': 1999, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 110, 'kinuy_mishari': 'SAXO', 'supply_index': 2}
# {'_id': 31514, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 53, 'degem_nm': 'VFAHXH-B2B01D', 'shnat_yitzur': 2017, 'mispar_rechavim_pailim': 56, 'mispar_rechavim_le_pailim': 8, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 31612, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 96, 'degem_nm': 'VBYHVM', 'shnat_yitzur': 2022, 'mispar_rechavim_pailim': 13, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 31625, 'sug_degem': 'M', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 32, 'degem_nm': 'GJ9HXC-TR', 'shnat_yitzur': 2008, 'mispar_rechavim_pailim': 1, 'mispar_rechavim_le_pailim': 3, 'kinuy_mishari': 'BERLINGO', 'supply_index': 2}
# {'_id': 31628, 'sug_degem': 'P', 'tozeret_cd': 516, 'tozeret_nm': 'סיטרואן סלובק', 'tozeret_eretz_nm': 'סלובקיה', 'tozar': 'סיטרואן', 'degem_cd': 6, 'degem_nm': 'SH9HP4/1', 'shnat_yitzur': 2014, 'mispar_rechavim_pailim': 17, 'mispar_rechavim_le_pailim': 5, 'kinuy_mishari': 'C3 PICASSO', 'supply_index': 2}
# {'_id': 31660, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 4, 'degem_nm': 'KF5FVA', 'shnat_yitzur': 2013, 'mispar_rechavim_pailim': 8, 'mispar_rechavim_le_pailim': 3, 'kinuy_mishari': 'DS5', 'supply_index': 2}
# {'_id': 31672, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 142, 'degem_nm': 'ECYHZR/B2F000', 'shnat_yitzur': 2020, 'mispar_rechavim_pailim': 3, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'BERLINGO', 'supply_index': 1}
# {'_id': 31673, 'sug_degem': 'M', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 17, 'degem_nm': 'XURHHA', 'shnat_yitzur': 2015, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'JUMPY', 'supply_index': 1}
# {'_id': 31716, 'sug_degem': 'M', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 650, 'degem_nm': 'GJWJYB', 'shnat_yitzur': 2004, 'mispar_rechavim_pailim': 2, 'mispar_rechavim_le_pailim': 47, 'kinuy_mishari': 'BERLINGO', 'supply_index': 2}
# {'_id': 31717, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 1141, 'degem_nm': 'N1NFZM', 'shnat_yitzur': 2000, 'mispar_rechavim_pailim': 5, 'mispar_rechavim_le_pailim': 722, 'kinuy_mishari': 'XSARA', 'supply_index': 2}
# {'_id': 31718, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 482, 'degem_nm': 'LCNFUF', 'shnat_yitzur': 2010, 'mispar_rechavim_pailim': 437, 'mispar_rechavim_le_pailim': 979, 'kinuy_mishari': 'C4', 'supply_index': 1}
# {'_id': 31725, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 220, 'degem_nm': 'FCKFVB', 'shnat_yitzur': 2005, 'mispar_rechavim_pailim': 5, 'mispar_rechavim_le_pailim': 15, 'kinuy_mishari': 'C3', 'supply_index': 1}
# {'_id': 31746, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 10, 'degem_nm': 'CHRHYB', 'shnat_yitzur': 2003, 'mispar_rechavim_pailim': 6, 'mispar_rechavim_le_pailim': 74, 'kinuy_mishari': 'XSARA PICASSO', 'supply_index': 2}
# {'_id': 31749, 'sug_degem': 'M', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 9, 'degem_nm': '7N9HP0', 'shnat_yitzur': 2015, 'mispar_rechavim_pailim': 285, 'mispar_rechavim_le_pailim': 164, 'kinuy_mishari': 'BERLINGO', 'supply_index': 2}
# {'_id': 31766, 'sug_degem': 'M', 'tozeret_cd': 1365, 'tozeret_nm': 'סיטרואן אנגליה', 'tozeret_eretz_nm': 'בריטניה', 'tozar': 'סיטרואן', 'degem_cd': 12, 'degem_nm': 'VFEHZ7', 'shnat_yitzur': 2022, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 4, 'kinuy_mishari': 'JUMPY', 'supply_index': 2}
# {'_id': 31814, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 54, 'degem_nm': 'DDHMZ6/PS', 'shnat_yitzur': 2016, 'mispar_rechavim_pailim': 3, 'mispar_rechavim_le_pailim': 5, 'kinuy_mishari': 'C-ELYSEE', 'supply_index': 1}
# {'_id': 31825, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 3600, 'degem_nm': 'X19C00', 'shnat_yitzur': 1996, 'mispar_rechavim_pailim': 1, 'mispar_rechavim_le_pailim': 8, 'kinuy_mishari': "V61 0.2 AITNAX 5 דל'", 'supply_index': 2}
# {'_id': 31838, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 86, 'degem_nm': '3AAHXT/1S', 'shnat_yitzur': 2017, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'C4 PICASSO', 'supply_index': 3}
# {'_id': 31842, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 157, 'degem_nm': 'ECYHZR', 'shnat_yitzur': 2020, 'mispar_rechavim_pailim': 63, 'mispar_rechavim_le_pailim': 2, 'kinuy_mishari': 'BERLINGO', 'supply_index': 2}
# {'_id': 31886, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 261, 'degem_nm': 'N2RHZN', 'shnat_yitzur': 2005, 'mispar_rechavim_pailim': 0, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'XSARA', 'supply_index': 1}
# {'_id': 31903, 'sug_degem': 'P', 'tozeret_cd': 817, 'tozeret_nm': 'סיטרואן צרפת', 'tozeret_eretz_nm': 'צרפת', 'tozar': 'סיטרואן', 'degem_cd': 542, 'degem_nm': 'RERHRJ', 'shnat_yitzur': 2007, 'mispar_rechavim_pailim': 1, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'C5', 'supply_index': 1}
# {'_id': 31934, 'sug_degem': 'P', 'tozeret_cd': 496, 'tozeret_nm': 'סיטרואן ספרד', 'tozeret_eretz_nm': 'ספרד', 'tozar': 'סיטרואן', 'degem_cd': 183, 'degem_nm': '2RHNS1', 'shnat_yitzur': 2022, 'mispar_rechavim_pailim': 8, 'mispar_rechavim_le_pailim': 1, 'kinuy_mishari': 'C3 AIRCROSS', 'supply_index': 1}
